# %% [markdown]
# # 0. Imports

# %%
from sklearn.linear_model import LinearRegression
from covid_project.data_utils import clean_covid_data, clean_policy_data, prep_policy_data
from covid_project.policy_mappings import policy_dict_v1
import pandas as pd
import statsmodels.api as sm
import os

# %% [markdown]
# # 1. Fit a simple model

# %%
# policy_name = 'manufacturing - start - state'
# bins_list = [(0, 7), (8, 14), (15, 28), (29, 60), (61, 999)]

# filename = policy_name.replace(" - ", "_") +\
#                 "-bins=" + ''.join([str(b[0])+"-"+str(b[1])+"_" for b in bins_list])[:-1] + ".csv"

# root_path = "./data/single_policy_bins/"

# data = pd.read_csv(root_path + filename, header=[0, 1], index_col=0)

def get_processed_data(policy_name,
                       bins_list,
                       root_path="./data/single_policy_bins/",):
    filename = policy_name.replace(" - ", "_") +\
                "-bins=" + ''.join([str(b[0])+"-"+str(b[1])+"_" for b in bins_list])[:-1] + ".csv"
    path = root_path + filename
    
    if os.path.exists(path):
        data = pd.read_csv(root_path + filename, header=[0, 1], index_col=0)
        return True, data
    else:
        return False, None

suc, data = get_processed_data('manufacturing - start - state',
                          bins_list = [(0, 7), (8, 14), (15, 28), (29, 60), (61, 999)])

# %%
data
# Out:
#                  info                                              \
#         location_type    state   county        date new_cases_1e6
# 69440          county  Alabama  autauga  2020-01-22          0.00
# 69441          county  Alabama  autauga  2020-01-23          0.00
# 69442          county  Alabama  autauga  2020-01-24          0.00
# 69443          county  Alabama  autauga  2020-01-25          0.00
# 69444          county  Alabama  autauga  2020-01-26          0.00
# ...               ...      ...      ...         ...           ...
# 2798268        county  Wyoming   weston  2021-12-26          0.00
# 2798269        county  Wyoming   weston  2021-12-27         14.08
# 2798270        county  Wyoming   weston  2021-12-28         28.17
# 2798271        county  Wyoming   weston  2021-12-29         42.25
# 2798272        county  Wyoming   weston  2021-12-30         28.17
#
#                                                                \
#         new_deaths_1e6 new_cases_7day_1e6 new_deaths_7day_1e6
# 69440              0.0           0.000000                 0.0
# 69441              0.0           0.000000                 0.0
# 69442              0.0           0.000000                 0.0
# 69443              0.0           0.000000                 0.0
# 69444              0.0           0.000000                 0.0
# ...                ...                ...                 ...
# 2798268            0.0          20.140845                 0.0
# 2798269            0.0          12.112676                 0.0
# 2798270            0.0          12.112676                 0.0
# 2798271            0.0          18.169014                 0.0
# 2798272            0.0          16.056338                 0.0
#
#         manufacturing - start - state
#                                   0-7 8-14 15-28 29-60 61-999
# 69440                               0    0     0     0      0
# 69441                               0    0     0     0      0
# 69442                               0    0     0     0      0
# 69443                               0    0     0     0      0
# 69444                               0    0     0     0      0
# ...                               ...  ...   ...   ...    ...
# 2798268                             0    0     0     0      0
# 2798269                             0    0     0     0      0
# 2798270                             0    0     0     0      0
# 2798271                             0    0     0     0      0
# 2798272                             0    0     0     0      0
#
# [2228387 rows x 13 columns]

# %%
data[policy_name]
# Out:
#          0-7  8-14  15-28  29-60  61-999
# 69440      0     0      0      0       0
# 69441      0     0      0      0       0
# 69442      0     0      0      0       0
# 69443      0     0      0      0       0
# 69444      0     0      0      0       0
# ...      ...   ...    ...    ...     ...
# 2798268    0     0      0      0       0
# 2798269    0     0      0      0       0
# 2798270    0     0      0      0       0
# 2798271    0     0      0      0       0
# 2798272    0     0      0      0       0
#
# [2228387 rows x 5 columns]

# %%
dep_var = 'new_cases_1e6'
y = data[('info', 'new_cases_1e6')]
X = data[policy_name]
X = sm.add_constant(X)

# %%
X
# Out:
#          const  0-7  8-14  15-28  29-60  61-999
# 69440      1.0    0     0      0      0       0
# 69441      1.0    0     0      0      0       0
# 69442      1.0    0     0      0      0       0
# 69443      1.0    0     0      0      0       0
# 69444      1.0    0     0      0      0       0
# ...        ...  ...   ...    ...    ...     ...
# 2798268    1.0    0     0      0      0       0
# 2798269    1.0    0     0      0      0       0
# 2798270    1.0    0     0      0      0       0
# 2798271    1.0    0     0      0      0       0
# 2798272    1.0    0     0      0      0       0
#
# [2228387 rows x 6 columns]

# %%
y
# Out:
# 69440       0.00
# 69441       0.00
# 69442       0.00
# 69443       0.00
# 69444       0.00
#            ...
# 2798268     0.00
# 2798269    14.08
# 2798270    28.17
# 2798271    42.25
# 2798272    28.17
# Name: (info, new_cases_1e6), Length: 2228387, dtype: float64

# %%
model = sm.OLS(y, X)
results = model.fit()

# %%
results.params
# Out:
# manufacturing - start - state_0-7       10.754544
# manufacturing - start - state_8-14      13.782788
# manufacturing - start - state_15-28     14.436798
# manufacturing - start - state_29-60     16.115160
# manufacturing - start - state_61-999    30.922036
# dtype: float64

# %%
results.__dict__.keys()
# Out:
# dict_keys(['_results', '__doc__'])

# %%
results._results._cache.keys()
# Out:
# dict_keys(['wresid', 'eigenvals', 'condition_number', 'ssr', 'uncentered_tss', 'rsquared', 'nobs', 'rsquared_adj', 'ess', 'mse_model', 'mse_resid', 'fvalue', 'f_pvalue', 'llf', 'aic', 'bic', 'scale', 'bse', 'tvalues', 'pvalues'])

# %%
results._results.__dict__.keys()
# Out:
# dict_keys(['params', 'model', 'k_constant', '_data_attr', '_data_in_cache', 'normalized_cov_params', '_use_t', '_cache', '_wexog_singular_values', 'df_model', 'df_resid', 'cov_type', 'cov_kwds', 'diagn'])

# %%
dir(results)
# Out:
# ['HC0_se',
#  'HC1_se',
#  'HC2_se',
#  'HC3_se',
#  '_HCCM',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abat_diagonal',
#  '_cache',
#  '_data_attr',
#  '_data_in_cache',
#  '_get_robustcov_results',
#  '_is_nested',
#  '_use_t',
#  '_wexog_singular_values',
#  'aic',
#  'bic',
#  'bse',
#  'centered_tss',
#  'compare_f_test',
#  'compare_lm_test',
#  'compare_lr_test',
#  'condition_number',
#  'conf_int',
#  'conf_int_el',
#  'cov_HC0',
#  'cov_HC1',
#  'cov_HC2',
#  'cov_HC3',
#  'cov_kwds',
#  'cov_params',
#  'cov_type',
#  'df_model',
#  'df_resid',
#  'diagn',
#  'eigenvals',
#  'el_test',
#  'ess',
#  'f_pvalue',
#  'f_test',
#  'fittedvalues',
#  'fvalue',
#  'get_influence',
#  'get_prediction',
#  'get_robustcov_results',
#  'info_criteria',
#  'initialize',
#  'k_constant',
#  'llf',
#  'load',
#  'model',
#  'mse_model',
#  'mse_resid',
#  'mse_total',
#  'nobs',
#  'normalized_cov_params',
#  'outlier_test',
#  'params',
#  'predict',
#  'pvalues',
#  'remove_data',
#  'resid',
#  'resid_pearson',
#  'rsquared',
#  'rsquared_adj',
#  'save',
#  'scale',
#  'ssr',
#  'summary',
#  'summary2',
#  't_test',
#  't_test_pairwise',
#  'tvalues',
#  'uncentered_tss',
#  'use_t',
#  'wald_test',
#  'wald_test_terms',
#  'wresid']

# %%
results._results._data_in_cache
# Out:
# ['fittedvalues', 'resid', 'wresid']

# %%
results.pvalues.to_dict()
# Out:
# {'manufacturing - start - state_0-7': 7.018221353441827e-89,
#  'manufacturing - start - state_8-14': 7.069141936740188e-127,
#  'manufacturing - start - state_15-28': 6.6695191796244436e-276,
#  'manufacturing - start - state_29-60': 0.0,
#  'manufacturing - start - state_61-999': 0.0}

# %%
results.df_model
# Out:
# 5.0

# %%
results.bse
# Out:
# manufacturing - start - state_0-7       0.538028
# manufacturing - start - state_8-14      0.575177
# manufacturing - start - state_15-28     0.406711
# manufacturing - start - state_29-60     0.269014
# manufacturing - start - state_61-999    0.066949
# dtype: float64

# %%
results.rsquared
# Out:
# 0.08953946831763915

# %%
summary = results.summary()
summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                     OLS Regression Results
# ==============================================================================================
# Dep. Variable:     ('info', 'new_cases_1e6')   R-squared (uncentered):                   0.090
# Model:                                   OLS   Adj. R-squared (uncentered):              0.090
# Method:                        Least Squares   F-statistic:                          4.383e+04
# Date:                       Sat, 11 Jun 2022   Prob (F-statistic):                        0.00
# Time:                               12:26:20   Log-Likelihood:                     -1.2309e+07
# No. Observations:                    2228387   AIC:                                  2.462e+07
# Df Residuals:                        2228382   BIC:                                  2.462e+07
# Df Model:                                  5
# Covariance Type:                   nonrobust
# ========================================================================================================
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# manufacturing - start - state_0-7       10.7545      0.538     19.989      0.000       9.700      11.809
# manufacturing - start - state_8-14      13.7828      0.575     23.963      0.000      12.655      14.910
# manufacturing - start - state_15-28     14.4368      0.407     35.496      0.000      13.640      15.234
# manufacturing - start - state_29-60     16.1152      0.269     59.904      0.000      15.588      16.642
# manufacturing - start - state_61-999    30.9220      0.067    461.875      0.000      30.791      31.053
# ==============================================================================
# Omnibus:                  5283027.126   Durbin-Watson:                   1.402
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):     417790315089.813
# Skew:                          23.189   Prob(JB):                         0.00
# Kurtosis:                    2123.731   Cond. No.                         8.59
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
def fit_ols_model_single_policy(data,
                                policy_name,
                                dep_var,
                                use_const=True):

    """Fit an ols model from statsmodels
    
    Parameters
    ----------
    data
    
    policy_name
    
    dep_var
    
    use_const
    
    Returns
    ---------
    dictionary containing the coefficience (params), standard error of the coefficients (std_err),
    r^2 value (r_squared) and the p values (p_values)
    """
    y = data[('info', dep_var)]
    X = data[policy_name]
    
    if use_const:
        X = sm.add_constant(X)

    model = sm.OLS(y, X)
    results = model.fit()

    results_dict = {
        'r_squared': results.rsquared,
        'p_values': results.pvalues.to_dict(),
        'params': results.params.to_dict(),
        'std_err': results.bse.to_dict()
    }
    
    return results_dict

# %%
res = fit_ols_model_single_policy(data,
                policy_name,
                'new_cases_1e6',
                True)

# %%
res
# Out:
# {'r_squared': 0.007396003861014577,
#  'p_values': {'const': 0.0,
#   '0-7': 1.5385998858129313e-91,
#   '8-14': 8.139974769145486e-42,
#   '15-28': 5.459562113357568e-68,
#   '29-60': 1.8709101287614066e-86,
#   '61-999': 0.0},
#  'params': {'const': 21.31820959496815,
#   '0-7': -10.56366564411765,
#   '8-14': -7.53542176528055,
#   '15-28': -6.881411953416204,
#   '29-60': -5.20304911135131,
#   '61-999': 9.603826833860145},
#  'std_err': {'const': 0.05097110775154247,
#   '0-7': 0.5205797232678747,
#   '8-14': 0.5561895787275343,
#   '15-28': 0.39493347624033953,
#   '29-60': 0.2640063492389575,
#   '61-999': 0.08218260084002933}}

# %% [markdown]
# # 2. Fit multiple models

# %% [markdown]
# get all policy names

# %%
def get_all_policies(policy_dict, min_samples):
    policy_data = clean_policy_data()
    policy_data_prepped = prep_policy_data(policy_data=policy_data,
                                           policy_dict=policy_dict,
                                           min_samples=min_samples)
    all_policies = policy_data_prepped['full_policy'].unique()
    return all_policies

all_policies = get_all_policies(policy_dict_v1, 3)

# %%
results = dict()
from tqdm.notebook import tqdm
for policy in tqdm(all_policies):
    suc, data = get_processed_data(policy, bins_list)
    res = fit_ols_model_single_policy(data,
                                      policy,
                                      'new_cases_1e6',
                                      True,)
    results[policy] = res
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
results
# Out:
# {'outdoor and recreation - stop - county': {'r_squared': 4.051495902146485e-05,
#   'p_values': {'const': 0.0,
#    '0-7': 8.293513825220407e-06,
#    '8-14': 0.0008766474070521422,
#    '15-28': 0.08208336956932982,
#    '29-60': 0.09726951966165569,
#    '61-999': 2.414554897300173e-13},
#   'params': {'const': 24.544402369635748,
#    '0-7': 18.84903513036451,
#    '8-14': 15.041728582745264,
#    '15-28': 5.558097630364793,
#    '29-60': -3.5064987238024554,
#    '61-999': 4.0912783178358145},
#   'std_err': {'const': 0.03936045994332847,
#    '0-7': 4.228636048168299,
#    '8-14': 4.520577608118154,
#    '15-28': 3.196652245461495,
#    '29-60': 2.1145927838053167,
#    '61-999': 0.5586417527211902}},
#  'non-essential businesses - stop - state': {'r_squared': 0.030231830752811883,
#   'p_values': {'const': 0.0,
#    '0-7': 9.405812061575971e-18,
#    '8-14': 4.328922614629604e-08,
#    '15-28': 1.9910929471460394e-11,
#    '29-60': 6.433177178181158e-174,
#    '61-999': 0.0},
#   'params': {'const': 9.928571048368108,
#    '0-7': 3.2197442749988348,
#    '8-14': 2.1914953428293633,
#    '15-28': 1.9301194665119035,
#    '29-60': 5.577609179938733,
#    '61-999': 22.13358932864955},
#   'std_err': {'const': 0.07441695295213317,
#    '0-7': 0.3752150306856857,
#    '8-14': 0.4001343829859788,
#    '15-28': 0.2877893390435547,
#    '29-60': 0.19836832402912777,
#    '61-999': 0.08860400651543116}},
#  'childcare - stop - county': {'r_squared': 1.948798555939657e-05,
#   'p_values': {'const': 0.0,
#    '0-7': 0.001310994365800281,
#    '8-14': 0.06737859246765654,
#    '15-28': 0.5712281872787743,
#    '29-60': 0.04154343305532519,
#    '61-999': 4.961539293536959e-07},
#   'params': {'const': 24.554888967307853,
#    '0-7': 15.691222143803927,
#    '8-14': 9.54796817554968,
#    '15-28': -2.090087380005893,
#    '29-60': -4.976225772863321,
#    '61-999': 3.213067894507869},
#   'std_err': {'const': 0.03933440670226138,
#    '0-7': 4.882806563486481,
#    '8-14': 5.21991861315709,
#    '15-28': 3.6911446411330253,
#    '29-60': 2.4416409197032256,
#    '61-999': 0.6390592560365538}},
#  'entertainment - stop - county': {'r_squared': 5.324421590668926e-05,
#   'p_values': {'const': 0.0,
#    '0-7': 0.03898324826730617,
#    '8-14': 0.23935935670733371,
#    '15-28': 0.660011507195603,
#    '29-60': 0.0014930986306171835,
#    '61-999': 3.549632426559043e-24},
#   'params': {'const': 24.53110838197849,
#    '0-7': 7.559985368021688,
#    '8-14': 4.606302332306688,
#    '15-28': -1.2178271319786569,
#    '29-60': 5.816528336771197,
#    '61-999': 4.9517952665489595},
#   'std_err': {'const': 0.039395177795182514,
#    '0-7': 3.6621361883611434,
#    '8-14': 3.9149599471916336,
#    '15-28': 2.768434879868683,
#    '29-60': 1.831385909783044,
#    '61-999': 0.4881789514035057}},
#  'gyms - stop - state': {'r_squared': 0.034303201282086415,
#   'p_values': {'const': 0.0,
#    '0-7': 2.223348051131038e-28,
#    '8-14': 2.089664239051545e-23,
#    '15-28': 3.015667292191602e-32,
#    '29-60': 2.588432293955865e-21,
#    '61-999': 0.0},
#   'params': {'const': 9.496200648928406,
#    '0-7': -4.2864607746268755,
#    '8-14': -4.124476287396232,
#    '15-28': -3.5167927279388485,
#    '29-60': 1.9421304657712855,
#    '61-999': 22.739746226889007},
#   'std_err': {'const': 0.0762327295635522,
#    '0-7': 0.38795419067020287,
#    '8-14': 0.41373839274385277,
#    '15-28': 0.29748183699763747,
#    '29-60': 0.20490408806848107,
#    '61-999': 0.08970315751225331}},
#  'mask mandate - stop - state': {'r_squared': 0.007658355415762985,
#   'p_values': {'const': 0.0,
#    '0-7': 0.01669676967922184,
#    '8-14': 0.07520526694147069,
#    '15-28': 0.5787605294461473,
#    '29-60': 1.3266166655426639e-06,
#    '61-999': 0.0},
#   'params': {'const': 21.87007487855317,
#    '0-7': 1.3367655508500926,
#    '8-14': 1.06194217280893,
#    '15-28': -0.23498598273267288,
#    '29-60': 1.3636296338194376,
#    '61-999': 12.594930474083442},
#   'std_err': {'const': 0.04511518226508261,
#    '0-7': 0.558540330685204,
#    '8-14': 0.5968611980716546,
#    '15-28': 0.42324854957479313,
#    '29-60': 0.2819899998290804,
#    '61-999': 0.09628901655513122}},
#  'non-essential businesses - stop - county': {'r_squared': 2.7204068801411907e-05,
#   'p_values': {'const': 0.0,
#    '0-7': 0.002639226632762444,
#    '8-14': 0.06760299612488595,
#    '15-28': 0.5229501654386335,
#    '29-60': 0.005138626969933083,
#    '61-999': 2.5587130216868095e-10},
#   'params': {'const': 24.550745568387434,
#    '0-7': 12.988656605526053,
#    '8-14': 8.439751326022893,
#    '15-28': -2.0859629596917078,
#    '29-60': -6.044346111865247,
#    '61-999': 3.64977698546208},
#   'std_err': {'const': 0.03935394703499287,
#    '0-7': 4.319605753814185,
#    '8-14': 4.617828837605245,
#    '15-28': 3.2654166584498907,
#    '29-60': 2.160071761992482,
#    '61-999': 0.5771832751365382}},
#  'personal care - stop - state': {'r_squared': 0.005425922129841054,
#   'p_values': {'const': 0.0,
#    '0-7': 5.776349767592004e-126,
#    '8-14': 3.2240419851541293e-77,
#    '15-28': 8.66352866740954e-93,
#    '29-60': 2.978307931233983e-76,
#    '61-999': 0.0},
#   'params': {'const': 22.559535699839856,
#    '0-7': -14.760255869029638,
#    '8-14': -12.289068838117513,
#    '15-28': -9.56929654451595,
#    '29-60': -5.760770951398356,
#    '61-999': 8.836167574949691},
#   'std_err': {'const': 0.04638129017250899,
#    '0-7': 0.6182302429157313,
#    '8-14': 0.6606833953206694,
#    '15-28': 0.4683234848534215,
#    '29-60': 0.311713933555204,
#    '61-999': 0.09007469265901145}},
#  'shelter in place - stop - county': {'r_squared': 0.0014496553834925097,
#   'p_values': {'const': 0.0,
#    '0-7': 9.133615239637115e-67,
#    '8-14': 3.8063344678858753e-60,
#    '15-28': 3.186769773432129e-128,
#    '29-60': 2.8821992460411556e-235,
#    '61-999': 5.8309123759695924e-207},
#   'params': {'const': 24.380010028127305,
#    '0-7': -19.25160423102591,
#    '8-14': -19.50175744013567,
#    '15-28': -20.320546260011433,
#    '29-60': -18.302506404938946,
#    '61-999': 4.324001684980819},
#   'std_err': {'const': 0.04121265122758686,
#    '0-7': 1.1152393568258545,
#    '8-14': 1.192139259691574,
#    '15-28': 0.8434733241540643,
#    '29-60': 0.5587607428221917,
#    '61-999': 0.14083566105101544}},
#  'outdoor and recreation - stop - state': {'r_squared': 0.01609747057117461,
#   'p_values': {'const': 0.0,
#    '0-7': 0.04152854931426985,
#    '8-14': 0.10689475117581822,
#    '15-28': 0.00015226159278271503,
#    '29-60': 3.635895196808176e-22,
#    '61-999': 0.0},
#   'params': {'const': 18.080800554449457,
#    '0-7': -0.8942021478066938,
#    '8-14': -0.7554600825335424,
#    '15-28': -1.2632742656576543,
#    '29-60': 2.172130325263453,
#    '61-999': 15.069494390328398},
#   'std_err': {'const': 0.05445363400046849,
#    '0-7': 0.43871825487790295,
#    '8-14': 0.4685577352821327,
#    '15-28': 0.3335502582434745,
#    '29-60': 0.22437095507813012,
#    '61-999': 0.08067436660622948}},
#  'houses of worship - stop - state': {'r_squared': 0.008037399696337877,
#   'p_values': {'const': 0.0,
#    '0-7': 8.002989005643968e-48,
#    '8-14': 6.1428032281686225e-40,
#    '15-28': 1.288249895656544e-47,
#    '29-60': 1.3907148436385999e-08,
#    '61-999': 0.0},
#   'params': {'const': 21.44390899042608,
#    '0-7': -7.844111945589245,
#    '8-14': -7.630621917444792,
#    '15-28': -5.933793501295634,
#    '29-60': -1.5499237662415026,
#    '61-999': 11.064850893034189},
#   'std_err': {'const': 0.048025427643103094,
#    '0-7': 0.5399016628178596,
#    '8-14': 0.5768936522949712,
#    '15-28': 0.4093364922399013,
#    '29-60': 0.2731360149332273,
#    '61-999': 0.08631309148838541}},
#  'houses of worship - stop - county': {'r_squared': 2.8296934481031322e-05,
#   'p_values': {'const': 0.0,
#    '0-7': 2.5606958278619874e-06,
#    '8-14': 0.0011335587318004377,
#    '15-28': 0.32630896720691926,
#    '29-60': 0.3200093494522097,
#    '61-999': 9.7516770888594e-08},
#   'params': {'const': 24.553015587748725,
#    '0-7': 24.357921912251214,
#    '8-14': 18.021895126536787,
#    '15-28': 3.8428772693942665,
#    '29-60': -2.575300743998782,
#    '61-999': 3.6695373696099445},
#   'std_err': {'const': 0.03932280432701405,
#    '0-7': 5.178956878880815,
#    '8-14': 5.536517839936131,
#    '15-28': 3.915008050749755,
#    '29-60': 2.589702357517513,
#    '61-999': 0.6882995043587486}},
#  'childcare - stop - state': {'r_squared': 0.009460327151337822,
#   'p_values': {'const': 0.0,
#    '0-7': 3.897931056853222e-78,
#    '8-14': 2.033372595401858e-68,
#    '15-28': 8.09934119653917e-121,
#    '29-60': 2.1053680375461995e-155,
#    '61-999': 0.0},
#   'params': {'const': 21.439220736378385,
#    '0-7': -8.685462830909232,
#    '8-14': -8.666453094220294,
#    '15-28': -8.241264715886178,
#    '29-60': -6.331619068442965,
#    '61-999': 11.596026105580048},
#   'std_err': {'const': 0.047990346646352336,
#    '0-7': 0.46412869775621585,
#    '8-14': 0.4957741736470668,
#    '15-28': 0.35258034024367263,
#    '29-60': 0.23839306489184622,
#    '61-999': 0.0850888971134272}},
#  'shelter in place - stop - state': {'r_squared': 0.025469724928170123,
#   'p_values': {'const': 0.0,
#    '0-7': 1.116517433115581e-49,
#    '8-14': 1.8537230323586924e-56,
#    '15-28': 9.392248600948389e-115,
#    '29-60': 8.220328918606906e-58,
#    '61-999': 0.0},
#   'params': {'const': 12.372346318231383,
#    '0-7': -5.721435091300382,
#    '8-14': -6.518327667708848,
#    '15-28': -6.747630226052752,
#    '29-60': -3.2799116805007165,
#    '61-999': 18.616087344040572},
#   'std_err': {'const': 0.07838958688053371,
#    '0-7': 0.38609772508849766,
#    '8-14': 0.41169105948458945,
#    '15-28': 0.29633971704012574,
#    '29-60': 0.20463762808462838,
#    '61-999': 0.09147279298344478}},
#  'entertainment - stop - state': {'r_squared': 0.034114040931629175,
#   'p_values': {'const': 0.0,
#    '0-7': 4.7787161214556605e-31,
#    '8-14': 1.443323777900241e-13,
#    '15-28': 7.170554347871058e-10,
#    '29-60': 2.1675409033052397e-96,
#    '61-999': 0.0},
#   'params': {'const': 8.817227304082422,
#    '0-7': 3.817913439243198,
#    '8-14': 2.5978653868567316,
#    '15-28': 1.5518027545303361,
#    '29-60': 3.6232973848566266,
#    '61-999': 23.42218628839105},
#   'std_err': {'const': 0.0737715708289551,
#    '0-7': 0.329485741462627,
#    '8-14': 0.3514273311317294,
#    '15-28': 0.2518217801408108,
#    '29-60': 0.17391136557255393,
#    '61-999': 0.08645095087734035}},
#  'manufacturing - stop - state': {'r_squared': 0.005095571787956499,
#   'p_values': {'const': 0.0,
#    '0-7': 0.16260130367281925,
#    '8-14': 1.308642132641537e-06,
#    '15-28': 4.146075278472423e-26,
#    '29-60': 0.003085977878202403,
#    '61-999': 0.0},
#   'params': {'const': 22.336558701318335,
#    '0-7': -0.8384961488414195,
#    '8-14': -3.1048650465264496,
#    '15-28': -4.808035251636274,
#    '29-60': -0.8961480694962604,
#    '61-999': 9.683295954958737},
#   'std_err': {'const': 0.045816389433199434,
#    '0-7': 0.6004800152965488,
#    '8-14': 0.6417065248921004,
#    '15-28': 0.45491010410285343,
#    '29-60': 0.30285048843966655,
#    '61-999': 0.09252335496009646}},
#  'manufacturing - stop - county': {'r_squared': 3.275112507405975e-05,
#   'p_values': {'const': 0.0,
#    '0-7': 0.00026920291859202917,
#    '8-14': 0.027164302727613766,
#    '15-28': 0.8579408570771713,
#    '29-60': 0.08824348707145124,
#    '61-999': 5.829424818794678e-13},
#   'params': {'const': 24.549831735534255,
#    '0-7': 18.86829326446576,
#    '8-14': 12.230971835894126,
#    '15-28': -0.7007692355342399,
#    '29-60': -4.414753610534251,
#    '61-999': 4.821638814459562},
#   'std_err': {'const': 0.039326445615253856,
#    '0-7': 5.178945372824905,
#    '8-14': 5.536505535705887,
#    '15-28': 3.9149993688520848,
#    '29-60': 2.5896966464568774,
#    '61-999': 0.6692578445054339}},
#  'mask mandate - stop - county': {'r_squared': 1.12568568341187e-05,
#   'p_values': {'const': 0.0,
#    '0-7': 0.8518359885231237,
#    '8-14': 0.5059993752815647,
#    '15-28': 0.2923541335279675,
#    '29-60': 0.005302325007380989,
#    '61-999': 7.367562399862288e-05},
#   'params': {'const': 24.562970276291917,
#    '0-7': -1.3679702762914123,
#    '8-14': -5.207434562006224,
#    '15-28': -5.82984527629203,
#    '29-60': -10.210509338791974,
#    '61-999': 4.214054707271786},
#   'std_err': {'const': 0.03928144088863986,
#    '0-7': 7.3241076746319305,
#    '8-14': 7.829786375531565,
#    '15-28': 5.536564716413073,
#    '29-60': 3.6622118427394024,
#    '61-999': 1.0630545588075169}},
#  'personal care - stop - county': {'r_squared': 3.142339903505764e-06,
#   'p_values': {'const': 0.0,
#    '0-7': 0.10162652729094819,
#    '8-14': 0.17536976807304075,
#    '15-28': 0.18588573867437197,
#    '29-60': 0.4843435926176214,
#    '61-999': 0.6192961419503796},
#   'params': {'const': 24.56734688809013,
#    '0-7': -19.57901355475625,
#    '8-14': -17.32687069761385,
#    '15-28': -11.959965935709793,
#    '29-60': -4.182138554756719,
#    '61-999': 0.7324064325924221},
#   'std_err': {'const': 0.03926601948048892,
#    '0-7': 11.960158712034055,
#    '8-14': 12.785938870024431,
#    '15-28': 9.041066712736871,
#    '29-60': 5.980176040007263,
#    '61-999': 1.4741049939979567}},
#  'executive order - stop - state': {'r_squared': 0.000641879753032315,
#   'p_values': {'const': 0.0,
#    '0-7': 1.0410586553023985e-11,
#    '8-14': 7.297786342371335e-12,
#    '15-28': 1.8337974591055313e-22,
#    '29-60': 1.1965461631972677e-54,
#    '61-999': 2.893169193668098e-218},
#   'params': {'const': 24.45669955448339,
#    '0-7': -17.606523773233263,
#    '8-14': -18.963016518769628,
#    '15-28': -19.084121429483943,
#    '29-60': -20.15999545292095,
#    '61-999': 10.746610074255269},
#   'std_err': {'const': 0.03953944948519253,
#    '0-7': 2.5889111976010577,
#    '8-14': 2.7676221393734144,
#    '15-28': 1.9572040867540468,
#    '29-60': 1.2949084227526322,
#    '61-999': 0.34074716427732166}},
#  'manufacturing - start - state': {'r_squared': 0.007396003861014577,
#   'p_values': {'const': 0.0,
#    '0-7': 1.5385998858129313e-91,
#    '8-14': 8.139974769145486e-42,
#    '15-28': 5.459562113357568e-68,
#    '29-60': 1.8709101287614066e-86,
#    '61-999': 0.0},
#   'params': {'const': 21.31820959496815,
#    '0-7': -10.56366564411765,
#    '8-14': -7.53542176528055,
#    '15-28': -6.881411953416204,
#    '29-60': -5.20304911135131,
#    '61-999': 9.603826833860145},
#   'std_err': {'const': 0.05097110775154247,
#    '0-7': 0.5205797232678747,
#    '8-14': 0.5561895787275343,
#    '15-28': 0.39493347624033953,
#    '29-60': 0.2640063492389575,
#    '61-999': 0.08218260084002933}},
#  'mask mandate - start - county': {'r_squared': 0.00019389624693477714,
#   'p_values': {'const': 0.0,
#    '0-7': 1.9900188494918973e-05,
#    '8-14': 9.86833173548567e-06,
#    '15-28': 1.420523957103651e-16,
#    '29-60': 5.754301865540914e-07,
#    '61-999': 9.56931539888294e-69},
#   'params': {'const': 24.398959132839828,
#    '0-7': 6.17399818423322,
#    '8-14': 6.838267347996398,
#    '15-28': 9.04256003092298,
#    '29-60': 3.621792391550325,
#    '61-999': 3.593356253588091},
#   'std_err': {'const': 0.04013348456276644,
#    '0-7': 1.4472512176118524,
#    '8-14': 1.5471022682259319,
#    '15-28': 1.0943345295048097,
#    '29-60': 0.7244598292225257,
#    '61-999': 0.2050583686836149}},
#  'entertainment - start - county': {'r_squared': 0.00017466277668032326,
#   'p_values': {'const': 0.0,
#    '0-7': 0.018828830563549042,
#    '8-14': 0.0004883571333855376,
#    '15-28': 3.220627027456622e-06,
#    '29-60': 8.6069934697523e-25,
#    '61-999': 1.7255304195276873e-56},
#   'params': {'const': 24.395652691826577,
#    '0-7': 3.1242382927739607,
#    '8-14': 4.956951317642623,
#    '15-28': 4.686292357638507,
#    '29-60': 6.854465701604099,
#    '61-999': 3.019116127893926},
#   'std_err': {'const': 0.040287516545199825,
#    '0-7': 1.330083242020075,
#    '8-14': 1.4215242585816472,
#    '15-28': 1.0064552715344823,
#    '29-60': 0.6667212577704127,
#    '61-999': 0.19063007903620807}},
#  'childcare - start - state': {'r_squared': 0.03668810080661644,
#   'p_values': {'const': 0.0,
#    '0-7': 0.10472693735019432,
#    '8-14': 0.4031206288463244,
#    '15-28': 0.23130303562420643,
#    '29-60': 5.619158111338612e-49,
#    '61-999': 0.0},
#   'params': {'const': 3.686844386393876,
#    '0-7': 0.5426265067086122,
#    '8-14': 0.29781193733003986,
#    '15-28': 0.3078021059197694,
#    '29-60': 2.6686730022304075,
#    '61-999': 27.033844845452297},
#   'std_err': {'const': 0.09559694208849048,
#    '0-7': 0.3344678737406502,
#    '8-14': 0.3562083471991495,
#    '15-28': 0.2571426067113954,
#    '29-60': 0.18142326500515307,
#    '61-999': 0.10381552367448627}},
#  'childcare - start - county': {'r_squared': 0.00020566379144271174,
#   'p_values': {'const': 0.0,
#    '0-7': 2.6498041624025696e-08,
#    '8-14': 1.167096238439685e-10,
#    '15-28': 2.735471121994475e-15,
#    '29-60': 1.802178792110704e-61,
#    '61-999': 2.6627454451213998e-12},
#   'params': {'const': 24.47643052171808,
#    '0-7': 9.741426795083429,
#    '8-14': 12.061680384179553,
#    '15-28': 10.462378642158983,
#    '29-60': 14.51294759722986,
#    '61-999': 1.830048502835933},
#   'std_err': {'const': 0.03978130175185547,
#    '0-7': 1.7510635689585743,
#    '8-14': 1.8718904945802899,
#    '15-28': 1.3239372901409778,
#    '29-60': 0.8772660132325263,
#    '61-999': 0.2616409489531812}},
#  'gyms - start - state': {'r_squared': 0.02772671166132279,
#   'p_values': {'const': 0.0,
#    '0-7': 5.832914249842926e-16,
#    '8-14': 4.6907950563538903e-07,
#    '15-28': 0.013420168349188253,
#    '29-60': 0.00034228523523551147,
#    '61-999': 0.0},
#   'params': {'const': 5.456367414327469,
#    '0-7': -3.1149581683086183,
#    '8-14': -2.0622571956544133,
#    '15-28': -0.7418822943126611,
#    '29-60': 0.7718100921723716,
#    '61-999': 24.03836087526573},
#   'std_err': {'const': 0.11204156865799851,
#    '0-7': 0.38490404671867273,
#    '8-14': 0.40929480963096654,
#    '15-28': 0.30006295530954,
#    '29-60': 0.21552903777823496,
#    '61-999': 0.12014168615272926}},
#  'houses of worship - start - state': {'r_squared': 0.016209947527735746,
#   'p_values': {'const': 0.0,
#    '0-7': 1.0372214163204597e-143,
#    '8-14': 6.398629755767779e-128,
#    '15-28': 2.449025844969027e-197,
#    '29-60': 2.9677354149526063e-86,
#    '61-999': 0.0},
#   'params': {'const': 17.599531770087292,
#    '0-7': -10.707776678437835,
#    '8-14': -10.775117455278098,
#    '15-28': -9.584389494847345,
#    '29-60': -4.2666021621443795,
#    '61-999': 13.46612324538295},
#   'std_err': {'const': 0.06314990757735679,
#    '0-7': 0.419468683115657,
#    '8-14': 0.4477952175606357,
#    '15-28': 0.31977215927687364,
#    '29-60': 0.2167473809506521,
#    '61-999': 0.08203623176168713}},
#  'outdoor and recreation - start - county': {'r_squared': 9.303104102631465e-05,
#   'p_values': {'const': 0.0,
#    '0-7': 0.08156504614968037,
#    '8-14': 0.7581228970431971,
#    '15-28': 0.5024150432340123,
#    '29-60': 2.423033924892017e-08,
#    '61-999': 1.1395602908394004e-39},
#   'params': {'const': 24.45905394749032,
#    '0-7': -2.5978946210653264,
#    '8-14': 0.4910274736793484,
#    '15-28': -0.7564447691038547,
#    '29-60': 4.165134847846457,
#    '61-999': 2.805156585523898},
#   'std_err': {'const': 0.04006937671273134,
#    '0-7': 1.4916049389028323,
#    '8-14': 1.594520832418851,
#    '15-28': 1.1278524371494516,
#    '29-60': 0.7466093286669665,
#    '61-999': 0.21282552770255744}},
#  'shelter in place - start - county': {'r_squared': 0.0014335320985102706,
#   'p_values': {'const': 0.0,
#    '0-7': 1.3952887569764622e-94,
#    '8-14': 5.5427309057536565e-73,
#    '15-28': 1.2278968682579976e-117,
#    '29-60': 2.1749568995704693e-263,
#    '61-999': 1.433997492602659e-140},
#   'params': {'const': 24.433124230629666,
#    '0-7': -21.137867506913086,
#    '8-14': -19.787741764684398,
#    '15-28': -17.868122484209664,
#    '29-60': -17.805503509358278,
#    '61-999': 3.2201047029073093},
#   'std_err': {'const': 0.041741690871957136,
#    '0-7': 1.024433011873758,
#    '8-14': 1.0950513098074497,
#    '15-28': 0.7748805520426805,
#    '29-60': 0.513490531092662,
#    '61-999': 0.12756692152691582}},
#  'medical - start - county': {'r_squared': 0.000259259727759642,
#   'p_values': {'const': 0.0,
#    '0-7': 0.0011675304917961005,
#    '8-14': 0.00044208273483712165,
#    '15-28': 3.2683545317102543e-07,
#    '29-60': 1.8196780280878312e-13,
#    '61-999': 4.751795549873666e-105},
#   'params': {'const': 24.51360536721183,
#    '0-7': -12.942586848693256,
#    '8-14': -14.973552457159284,
#    '15-28': -15.390986319592498,
#    '29-60': -14.674947959804317,
#    '61-999': 11.413765401406927},
#   'std_err': {'const': 0.03937110903352286,
#    '0-7': 3.986381946651268,
#    '8-14': 4.261595578326315,
#    '15-28': 3.013531728506906,
#    '29-60': 1.9934825856569196,
#    '61-999': 0.5243292011298619}},
#  'non-essential businesses - start - state': {'r_squared': 0.033591075367448764,
#   'p_values': {'const': 0.0,
#    '0-7': 0.9219805472645137,
#    '8-14': 0.04522895075213536,
#    '15-28': 0.0002657180075819265,
#    '29-60': 8.141745215281888e-60,
#    '61-999': 0.0},
#   'params': {'const': 5.645237112544671,
#    '0-7': 0.03708820432249346,
#    '8-14': 0.8076321014394755,
#    '15-28': 1.0671592382608253,
#    '29-60': 3.35564767783559,
#    '61-999': 25.224715011208968},
#   'std_err': {'const': 0.09286023954630343,
#    '0-7': 0.37868583862987304,
#    '8-14': 0.4033078744124968,
#    '15-28': 0.2926433543169305,
#    '29-60': 0.2057134151219855,
#    '61-999': 0.10308525365746116}},
#  'mask mandate - start - state': {'r_squared': 0.027667007579969427,
#   'p_values': {'const': 0.0,
#    '0-7': 0.22677413308567865,
#    '8-14': 8.388186299400775e-21,
#    '15-28': 3.4812970586689016e-66,
#    '29-60': 2.597328555629408e-213,
#    '61-999': 0.0},
#   'params': {'const': 10.610752938211412,
#    '0-7': 0.3445297774485255,
#    '8-14': -2.8413909635279806,
#    '15-28': -3.7496360829359485,
#    '29-60': -4.673939459603004,
#    '61-999': 20.459513337237066},
#   'std_err': {'const': 0.07872233807580441,
#    '0-7': 0.28503907016227087,
#    '8-14': 0.3037382079972659,
#    '15-28': 0.21819402968672438,
#    '29-60': 0.14992657086648137,
#    '61-999': 0.08835412967012983}},
#  'housing - start - state': {'r_squared': 0.019442800016493234,
#   'p_values': {'const': 0.0,
#    '0-7': 0.0,
#    '8-14': 0.0,
#    '15-28': 0.0,
#    '29-60': 0.0,
#    '61-999': 0.0},
#   'params': {'const': 18.94973018684662,
#    '0-7': -17.899397568764254,
#    '8-14': -17.87226471725378,
#    '15-28': -17.059694275427397,
#    '29-60': -12.953218296966188,
#    '61-999': 11.430965041549971},
#   'std_err': {'const': 0.07204950722460972,
#    '0-7': 0.2949949258794475,
#    '8-14': 0.31482502788470385,
#    '15-28': 0.22488205629841182,
#    '29-60': 0.15244507380773475,
#    '61-999': 0.08385180359899035}},
#  'non-essential businesses - start - county': {'r_squared': 8.989506856382778e-05,
#   'p_values': {'const': 0.0,
#    '0-7': 0.7991763915437585,
#    '8-14': 0.23047399142731395,
#    '15-28': 0.4131943824009159,
#    '29-60': 1.5535755819336312e-18,
#    '61-999': 1.4709101336833437e-28},
#   'params': {'const': 24.470764572568413,
#    '0-7': -0.40432339609749013,
#    '8-14': 2.0372186207086744,
#    '15-28': 0.9832816459190428,
#    '29-60': 6.987989103902376,
#    '61-999': 2.5246198738609227},
#   'std_err': {'const': 0.03996041884219481,
#    '0-7': 1.5892391766497433,
#    '8-14': 1.6989010082030112,
#    '15-28': 1.2016366902578761,
#    '29-60': 0.7953728160147618,
#    '61-999': 0.22773216313425862}},
#  'medical - start - state': {'r_squared': 0.032328714620041166,
#   'p_values': {'const': 0.0,
#    '0-7': 0.002470641471043394,
#    '8-14': 0.040783928075161936,
#    '15-28': 0.0008270698878452619,
#    '29-60': 0.0,
#    '61-999': 0.0},
#   'params': {'const': 5.797402781181508,
#    '0-7': -0.7121662114046875,
#    '8-14': -0.5054651059410556,
#    '15-28': -0.6593703341823461,
#    '29-60': -12.12089285059535,
#    '61-999': 23.90884385563492},
#   'std_err': {'const': 0.12079075426865099,
#    '0-7': 0.23527770300201803,
#    '8-14': 0.24708406575064784,
#    '15-28': 0.19720504727961383,
#    '29-60': 0.14170661259942968,
#    '61-999': 0.12529917596225335}},
#  'houses of worship - start - county': {'r_squared': 6.220071953111361e-05,
#   'p_values': {'const': 0.0,
#    '0-7': 1.731481525567075e-06,
#    '8-14': 0.0015676635983617347,
#    '15-28': 0.0042585308100258745,
#    '29-60': 0.22761728370640968,
#    '61-999': 8.150458173173859e-23},
#   'params': {'const': 24.5140524042651,
#    '0-7': 11.147703924849036,
#    '8-14': 7.878840904956711,
#    '15-28': 5.037032586693553,
#    '29-60': 1.4067703805450242,
#    '61-999': 3.44267525305895},
#   'std_err': {'const': 0.0395448611117933,
#    '0-7': 2.330941461839123,
#    '8-14': 2.4918364138041906,
#    '15-28': 1.762216290527216,
#    '29-60': 1.1659737868664835,
#    '61-999': 0.3501256017915026}},
#  'outdoor and recreation - start - state': {'r_squared': 0.027261040189205166,
#   'p_values': {'const': 0.0,
#    '0-7': 1.048516720691949e-65,
#    '8-14': 5.17199210793139e-57,
#    '15-28': 1.877546368454391e-96,
#    '29-60': 2.4843922740003014e-75,
#    '61-999': 0.0},
#   'params': {'const': 11.223693585247076,
#    '0-7': -6.669301224135858,
#    '8-14': -6.608286343183553,
#    '15-28': -6.239313128897489,
#    '29-60': -3.810143780559521,
#    '61-999': 19.608732303742467},
#   'std_err': {'const': 0.0824736320737357,
#    '0-7': 0.3895437924085568,
#    '8-14': 0.4152715169698098,
#    '15-28': 0.2993762956496751,
#    '29-60': 0.2074548542251621,
#    '61-999': 0.0945526141485158}},
#  'state of emergency - start - state': {'r_squared': 0.027591898617093324,
#   'p_values': {'const': 1.0750857826779048e-05,
#    '0-7': 0.010258794626465697,
#    '8-14': 0.3791290816687696,
#    '15-28': 5.460223383192421e-09,
#    '29-60': 2.3974081026932554e-64,
#    '61-999': 0.0},
#   'params': {'const': 0.64071489556208,
#    '0-7': -0.9957587263833643,
#    '8-14': -0.3616269165030912,
#    '15-28': 1.7949473184291436,
#    '29-60': 3.895091367162172,
#    '61-999': 28.0787588350705},
#   'std_err': {'const': 0.14556729800076118,
#    '0-7': 0.3879099619421641,
#    '8-14': 0.41117222397522185,
#    '15-28': 0.30774788543497844,
#    '29-60': 0.22996679717190044,
#    '61-999': 0.15125085864916357}},
#  'wholesale trade - start - county': {'r_squared': 3.2709525083829405e-05,
#   'p_values': {'const': 0.0,
#    '0-7': 0.028064304091325695,
#    '8-14': 0.03659580109363586,
#    '15-28': 0.003318666739622022,
#    '29-60': 8.604725971386685e-06,
#    '61-999': 2.8991015686156084e-09},
#   'params': {'const': 24.562015468660984,
#    '0-7': -20.347765468660835,
#    '8-14': -20.701444040089235,
#    '15-28': -20.56515832580364,
#    '29-60': -20.611390468661135,
#    '61-999': 6.892815903887513},
#   'std_err': {'const': 0.03927506215144479,
#    '0-7': 9.264195466316464,
#    '8-14': 9.903830417530575,
#    '15-28': 7.003120713999283,
#    '29-60': 4.6322226098720165,
#    '61-999': 1.1609469524109783}},
#  'entertainment - start - state': {'r_squared': 0.03499462454428026,
#   'p_values': {'const': 0.0,
#    '0-7': 1.5784468525397754e-30,
#    '8-14': 4.98792146125402e-35,
#    '15-28': 4.419348285055396e-43,
#    '29-60': 9.334197170907297e-121,
#    '61-999': 0.0},
#   'params': {'const': 6.756171281071445,
#    '0-7': -3.6502384613411376,
#    '8-14': -4.166933676542598,
#    '15-28': -3.380012967823689,
#    '29-60': -4.0432718926930225,
#    '61-999': 24.065873649797442},
#   'std_err': {'const': 0.09209822735435798,
#    '0-7': 0.3178356749057798,
#    '8-14': 0.3374498086638874,
#    '15-28': 0.24563059094513948,
#    '29-60': 0.17302538508412202,
#    '61-999': 0.10068633560868409}},
#  'shelter in place - start - state': {'r_squared': 0.018619953017554813,
#   'p_values': {'const': 0.0,
#    '0-7': 2.6970842742976864e-154,
#    '8-14': 3.0921806437980103e-99,
#    '15-28': 1.7500087295160947e-125,
#    '29-60': 2.018367097193251e-233,
#    '61-999': 0.0},
#   'params': {'const': 13.68081595892107,
#    '0-7': -10.294783744132507,
#    '8-14': -8.763361535106245,
#    '15-28': -7.15216079827969,
#    '29-60': -6.855743406501066,
#    '61-999': 15.462467286576834},
#   'std_err': {'const': 0.09247190629310563,
#    '0-7': 0.3890183871455525,
#    '8-14': 0.4144277686984116,
#    '15-28': 0.3001501220127502,
#    '29-60': 0.21013373931730941,
#    '61-999': 0.10281543341934374}},
#  'nursing homes - start - state': {'r_squared': 0.010461510762345916,
#   'p_values': {'const': 0.0,
#    '0-7': 0.0,
#    '8-14': 0.0,
#    '15-28': 0.0,
#    '29-60': 0.0,
#    '61-999': 0.0},
#   'params': {'const': 21.80369813673551,
#    '0-7': -19.910592867573122,
#    '8-14': -18.961962016705115,
#    '15-28': -17.44122479356717,
#    '29-60': -16.562935349673932,
#    '61-999': 7.289115297290679},
#   'std_err': {'const': 0.05896475111249309,
#    '0-7': 0.4651547128886229,
#    '8-14': 0.49678575490503146,
#    '15-28': 0.3536145180255846,
#    '29-60': 0.23777535021408047,
#    '61-999': 0.08029968237322896}},
#  'manufacturing - start - county': {'r_squared': 0.00012056950641670117,
#   'p_values': {'const': 0.0,
#    '0-7': 1.3266530491526571e-06,
#    '8-14': 0.023084158032357985,
#    '15-28': 0.6169855864721654,
#    '29-60': 5.486411075523905e-08,
#    '61-999': 1.2491690352665216e-47},
#   'params': {'const': 24.511531155860606,
#    '0-7': 12.826706549057727,
#    '8-14': 6.442567204795244,
#    '15-28': 1.002883364045795,
#    '29-60': -7.21025554110695,
#    '61-999': 5.6942602142465315},
#   'std_err': {'const': 0.039480961786662244,
#    '0-7': 2.652484932839163,
#    '8-14': 2.8355864045874046,
#    '15-28': 2.0052567172589275,
#    '29-60': 1.3266831345473034,
#    '61-999': 0.39275523204247453}},
#  'personal care - start - state': {'r_squared': 0.01375209695969648,
#   'p_values': {'const': 0.0,
#    '0-7': 1.5462460751919558e-200,
#    '8-14': 3.0022868780545097e-189,
#    '15-28': 0.0,
#    '29-60': 0.0,
#    '61-999': 0.0},
#   'params': {'const': 19.431328657861858,
#    '0-7': -13.742308955795611,
#    '8-14': -14.252247172312348,
#    '15-28': -13.290743087737756,
#    '29-60': -8.819621696064702,
#    '61-999': 11.477894725459114},
#   'std_err': {'const': 0.05873586950202501,
#    '0-7': 0.45478431748878684,
#    '8-14': 0.4856777740000859,
#    '15-28': 0.34592831809772595,
#    '29-60': 0.233012061132148,
#    '61-999': 0.08045465588684814}},
#  'travel - start - state': {'r_squared': 0.0011008625095069169,
#   'p_values': {'const': 0.0,
#    '0-7': 3.000553397775822e-36,
#    '8-14': 9.592429987726056e-27,
#    '15-28': 1.6195921657665092e-48,
#    '29-60': 2.0286125509376996e-89,
#    '61-999': 0.0},
#   'params': {'const': 24.323696766793756,
#    '0-7': -17.323693398338175,
#    '8-14': -15.768871179627673,
#    '15-28': -15.252471053206218,
#    '29-60': -13.834659935949219,
#    '61-999': 7.957999636423034},
#   'std_err': {'const': 0.04017913001695527,
#    '0-7': 1.3779062799119575,
#    '8-14': 1.4729517435444468,
#    '15-28': 1.0419896105294872,
#    '29-60': 0.6899853785583129,
#    '61-999': 0.19543691723726853}},
#  'gatherings - start - state': {'r_squared': 0.0017873836635093898,
#   'p_values': {'const': 0.0,
#    '0-7': 2.0097328402662064e-39,
#    '8-14': 1.304076219689629e-32,
#    '15-28': 5.5538359650602545e-68,
#    '29-60': 4.695645176803946e-135,
#    '61-999': 0.0},
#   'params': {'const': 24.22723676331715,
#    '0-7': -18.25710162818206,
#    '8-14': -17.66626507734524,
#    '15-28': -18.308819774900307,
#    '29-60': -17.20841778809218,
#    '61-999': 9.744232283137304},
#   'std_err': {'const': 0.040275812369466604,
#    '0-7': 1.3896755769413522,
#    '8-14': 1.4855476879452405,
#    '15-28': 1.0508268349784409,
#    '29-60': 0.6957126979460118,
#    '61-999': 0.18744951452055408}},
#  'education - start - state': {'r_squared': 0.0011723161169204799,
#   'p_values': {'const': 0.0,
#    '0-7': 1.1694159916383322e-38,
#    '8-14': 1.7158161998088534e-34,
#    '15-28': 6.522403430285313e-68,
#    '29-60': 1.636598285070317e-107,
#    '61-999': 0.0},
#   'params': {'const': 24.340366239509077,
#    '0-7': -18.96134933128717,
#    '8-14': -19.06287966095777,
#    '15-28': -19.298034473466615,
#    '29-60': -16.21973443186154,
#    '61-999': 7.2311740655466945},
#   'std_err': {'const': 0.04024641603609937,
#    '0-7': 1.4581502039134124,
#    '8-14': 1.5563446952806084,
#    '15-28': 1.108187542045147,
#    '29-60': 0.7363629672091689,
#    '61-999': 0.18992162461371448}},
#  'personal care - start - county': {'r_squared': 5.489116359891355e-06,
#   'p_values': {'const': 0.0,
#    '0-7': 0.12113951212784575,
#    '8-14': 0.18090343168825265,
#    '15-28': 0.04659943083732188,
#    '29-60': 0.10459666537967806,
#    '61-999': 0.22987763725230914},
#   'params': {'const': 24.56683725039393,
#    '0-7': -10.703226139283045,
#    '8-14': -9.876995980552834,
#    '15-28': -10.387313440869956,
#    '29-60': -5.603781694838843,
#    '61-999': 1.0181010986135621},
#   'std_err': {'const': 0.0392974893644076,
#    '0-7': 6.90526735619968,
#    '8-14': 7.382026374842051,
#    '15-28': 5.219954870089719,
#    '29-60': 3.4528014038819603,
#    '61-999': 0.8479410053854091}},
#  'construction - start - county': {'r_squared': 2.7816295218863196e-05,
#   'p_values': {'const': 0.0,
#    '0-7': 0.049968261307582994,
#    '8-14': 0.061843488061227386,
#    '15-28': 0.008837339450036914,
#    '29-60': 7.762308709589661e-05,
#    '61-999': 1.4135031513141867e-08},
#   'params': {'const': 24.562590172152863,
#    '0-7': -20.303527672152796,
#    '8-14': -20.677590172152655,
#    '15-28': -20.50044731500993,
#    '29-60': -20.465324547152772,
#    '61-999': 7.361002965102251},
#   'std_err': {'const': 0.0392701208429223,
#    '0-7': 10.357692116895818,
#    '8-14': 11.072828685989071,
#    '15-28': 7.829721490947569,
#    '29-60': 5.178957723701905,
#    '61-999': 1.297832615108024}},
#  'executive order - start - state': {'r_squared': 0.0005045162561688743,
#   'p_values': {'const': 0.0,
#    '0-7': 2.4389532363909347e-15,
#    '8-14': 2.1940102019741424e-12,
#    '15-28': 3.290735824182005e-18,
#    '29-60': 7.875157186972512e-48,
#    '61-999': 8.416216516727151e-159},
#   'params': {'const': 24.47291556048928,
#    '0-7': -20.49719290423924,
#    '8-14': -19.43447806048983,
#    '15-28': -17.030884310489835,
#    '29-60': -18.81616751361434,
#    '61-999': 8.874444818527095},
#   'std_err': {'const': 0.039559475897605854,
#    '0-7': 2.5890893810557687,
#    '8-14': 2.767812587395902,
#    '15-28': 1.957338942426971,
#    '29-60': 1.294997942034392,
#    '61-999': 0.33049159298271097}}}
