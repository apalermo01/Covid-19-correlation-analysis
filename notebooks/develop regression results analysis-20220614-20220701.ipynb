# %% [markdown]
# # 0. Imports

# %%
import json
import os
import pandas as pd
import numpy as np

# %% [markdown]
# # 1. generate dataframe to hold results

# %%
path = "./data/regression_results/"
results_files = os.listdir(path)

#all_results = dict()
#df_list = []

cols = ['dep_var', 'policy', 'bins_list', 'bin', 'r_squared', 'p_value', 'param', 'std_err']
all_data = dict()
pk = 0
for r in results_files:
    if 'bins' not in r:
        continue
    dep_var = r.split('bins')[0][:-1]
#     print("r = ", r)
    bins_str = r.split('=')[1].split('.')[0]
    bins_list = [(int(e.split('-')[0]), int(e.split('-')[1]))
                  for e in bins_str.split('_')]
    with open(path+r, "r") as f:
        data = json.load(f)
        
    for policy in data:
        r2 = data[policy]['r_squared']
        
        for b in data[policy]['p_values']:
            all_data[pk] = {
                'dep_var': dep_var,
                'bins_list': str(bins_list),
                'policy': policy,
                'bin': b,
                'rsquared': r2,
                'p_value': data[policy]['p_values'][b],
                'param': data[policy]['params'][b],
                'std_err': data[policy]['std_err'][b]
            }
            pk += 1
                
    df = pd.DataFrame.from_dict(all_data, orient='index')

# %%
df
# Out:
#                   dep_var                       bins_list  \
# 0     new_deaths_7day_1e6  [(0, 14), (15, 28), (29, 999)]
# 1     new_deaths_7day_1e6  [(0, 14), (15, 28), (29, 999)]
# 2     new_deaths_7day_1e6  [(0, 14), (15, 28), (29, 999)]
# 3     new_deaths_7day_1e6  [(0, 14), (15, 28), (29, 999)]
# 4     new_deaths_7day_1e6  [(0, 14), (15, 28), (29, 999)]
# ...                   ...                             ...
# 3395       new_deaths_1e6    [(0, 7), (8, 14), (15, 999)]
# 3396       new_deaths_1e6    [(0, 7), (8, 14), (15, 999)]
# 3397       new_deaths_1e6    [(0, 7), (8, 14), (15, 999)]
# 3398       new_deaths_1e6    [(0, 7), (8, 14), (15, 999)]
# 3399       new_deaths_1e6    [(0, 7), (8, 14), (15, 999)]
#
#                                        policy     bin  rsquared       p_value  \
# 0      outdoor and recreation - stop - county   const  0.000026  0.000000e+00
# 1      outdoor and recreation - stop - county    0-14  0.000026  1.130057e-06
# 2      outdoor and recreation - stop - county   15-28  0.000026  6.960655e-09
# 3      outdoor and recreation - stop - county  29-999  0.000026  5.084651e-01
# 4     non-essential businesses - stop - state   const  0.014947  0.000000e+00
# ...                                       ...     ...       ...           ...
# 3395            construction - start - county  15-999  0.000003  5.652222e-03
# 3396          executive order - start - state   const  0.000009  0.000000e+00
# 3397          executive order - start - state     0-7  0.000009  1.094240e-03
# 3398          executive order - start - state    8-14  0.000009  5.065421e-03
# 3399          executive order - start - state  15-999  0.000009  4.053824e-01
#
#          param   std_err
# 0     0.430151  0.000771
# 1     0.294389  0.060480
# 2     0.362587  0.062602
# 3     0.006996  0.010581
# 4     0.215626  0.001469
# ...        ...       ...
# 3395 -0.155881  0.056330
# 3396  0.435227  0.001793
# 3397 -0.383176  0.117355
# 3398 -0.351633  0.125456
# 3399  0.011933  0.014342
#
# [3400 rows x 8 columns]

# %%
df.sort_values(by='rsquared', ascending=False)
# Out:
#                  dep_var                                         bins_list  \
# 643   new_cases_7day_1e6  [(0, 7), (8, 14), (15, 28), (29, 60), (61, 999)]
# 642   new_cases_7day_1e6  [(0, 7), (8, 14), (15, 28), (29, 60), (61, 999)]
# 639   new_cases_7day_1e6  [(0, 7), (8, 14), (15, 28), (29, 60), (61, 999)]
# 640   new_cases_7day_1e6  [(0, 7), (8, 14), (15, 28), (29, 60), (61, 999)]
# 641   new_cases_7day_1e6  [(0, 7), (8, 14), (15, 28), (29, 60), (61, 999)]
# ...                  ...                                               ...
# 1556      new_deaths_1e6                              [(0, 14), (15, 999)]
# 1555      new_deaths_1e6                              [(0, 14), (15, 999)]
# 1510      new_deaths_1e6                              [(0, 14), (15, 999)]
# 1511      new_deaths_1e6                              [(0, 14), (15, 999)]
# 1509      new_deaths_1e6                              [(0, 14), (15, 999)]
#
#                              policy     bin  rsquared       p_value  \
# 643       childcare - start - state  61-999  0.106255  0.000000e+00
# 642       childcare - start - state   29-60  0.106255  4.552545e-73
# 639       childcare - start - state     0-7  0.106255  3.268474e-04
# 640       childcare - start - state    8-14  0.106255  4.537082e-03
# 641       childcare - start - state   15-28  0.106255  2.413168e-03
# ...                             ...     ...       ...           ...
# 1556  personal care - stop - county  15-999  0.000001  1.080018e-01
# 1555  personal care - stop - county    0-14  0.000001  4.484749e-01
# 1510  entertainment - stop - county    0-14  0.000001  2.577822e-01
# 1511  entertainment - stop - county  15-999  0.000001  2.983866e-01
# 1509  entertainment - stop - county   const  0.000001  0.000000e+00
#
#           param   std_err
# 643   26.913827  0.058712
# 642    1.855164  0.102603
# 639    0.679647  0.189156
# 640    0.571758  0.201452
# 641    0.441225  0.145426
# ...         ...       ...
# 1556  -0.102967  0.064064
# 1555  -0.300007  0.395808
# 1510   0.137159  0.121203
# 1511  -0.021927  0.021085
# 1509   0.435382  0.001785
#
# [3400 rows x 8 columns]

# %%
df.sort_values(by='p_value')
# Out:
#                   dep_var                                         bins_list  \
# 0     new_deaths_7day_1e6                    [(0, 14), (15, 28), (29, 999)]
# 1265        new_cases_1e6  [(0, 7), (8, 14), (15, 28), (29, 60), (61, 999)]
# 1260        new_cases_1e6  [(0, 7), (8, 14), (15, 28), (29, 60), (61, 999)]
# 1259        new_cases_1e6  [(0, 7), (8, 14), (15, 28), (29, 60), (61, 999)]
# 2719   new_cases_7day_1e6                    [(0, 14), (15, 28), (29, 999)]
# ...                   ...                                               ...
# 90    new_deaths_7day_1e6                    [(0, 14), (15, 28), (29, 999)]
# 2775   new_cases_7day_1e6                    [(0, 14), (15, 28), (29, 999)]
# 2953       new_deaths_1e6  [(0, 7), (8, 14), (15, 28), (29, 60), (61, 999)]
# 664    new_cases_7day_1e6  [(0, 7), (8, 14), (15, 28), (29, 60), (61, 999)]
# 1910   new_cases_7day_1e6                      [(0, 7), (8, 14), (15, 999)]
#
#                                        policy     bin  rsquared   p_value  \
# 0      outdoor and recreation - stop - county   const  0.000026  0.000000
# 1265         houses of worship - stop - state  61-999  0.008037  0.000000
# 1260         houses of worship - stop - state   const  0.008037  0.000000
# 1259    outdoor and recreation - stop - state  61-999  0.016097  0.000000
# 2719                      gyms - stop - state  29-999  0.084424  0.000000
# ...                                       ...     ...       ...       ...
# 90             entertainment - start - county   15-28  0.000028  0.978412
# 2775            personal care - stop - county  29-999  0.000009  0.990113
# 2953         shelter in place - stop - county  61-999  0.000095  0.993470
# 664   outdoor and recreation - start - county    8-14  0.000247  0.994336
# 1910  outdoor and recreation - start - county    8-14  0.000239  0.994336
#
#           param   std_err
# 0      0.430151  0.000771
# 1265  11.064851  0.086313
# 1260  21.443909  0.048025
# 1259  15.069494  0.080674
# 2719  21.433946  0.050867
# ...         ...       ...
# 90    -0.000533  0.019711
# 2775   0.010414  0.840387
# 2953  -0.000052  0.006386
# 664   -0.006645  0.936139
# 1910  -0.006645  0.936142
#
# [3400 rows x 8 columns]

# %%
df[(df['dep_var'] == 'new_cases_1e6') & (df['bins_list'] == '[(0, 14), (15, 28), (29, 999)]')]
# Out:
#             dep_var                       bins_list  \
# 2500  new_cases_1e6  [(0, 14), (15, 28), (29, 999)]
# 2501  new_cases_1e6  [(0, 14), (15, 28), (29, 999)]
# 2502  new_cases_1e6  [(0, 14), (15, 28), (29, 999)]
# 2503  new_cases_1e6  [(0, 14), (15, 28), (29, 999)]
# 2504  new_cases_1e6  [(0, 14), (15, 28), (29, 999)]
# ...             ...                             ...
# 2695  new_cases_1e6  [(0, 14), (15, 28), (29, 999)]
# 2696  new_cases_1e6  [(0, 14), (15, 28), (29, 999)]
# 2697  new_cases_1e6  [(0, 14), (15, 28), (29, 999)]
# 2698  new_cases_1e6  [(0, 14), (15, 28), (29, 999)]
# 2699  new_cases_1e6  [(0, 14), (15, 28), (29, 999)]
#
#                                        policy     bin  rsquared  \
# 2500   outdoor and recreation - stop - county   const  0.000035
# 2501   outdoor and recreation - stop - county    0-14  0.000035
# 2502   outdoor and recreation - stop - county   15-28  0.000035
# 2503   outdoor and recreation - stop - county  29-999  0.000035
# 2504  non-essential businesses - stop - state   const  0.026928
# ...                                       ...     ...       ...
# 2695            construction - start - county  29-999  0.000016
# 2696          executive order - start - state   const  0.000312
# 2697          executive order - start - state    0-14  0.000312
# 2698          executive order - start - state   15-28  0.000312
# 2699          executive order - start - state  29-999  0.000312
#
#             p_value      param   std_err
# 2500   0.000000e+00  24.544402  0.039361
# 2501   3.237821e-08  17.072292  3.088283
# 2502   8.208409e-02   5.558098  3.196660
# 2503   2.758739e-11   3.597741  0.540287
# 2504   0.000000e+00   9.928571  0.074544
# ...             ...        ...       ...
# 2695   5.576166e-06   5.718120  1.258981
# 2696   0.000000e+00  24.472916  0.039563
# 2697   3.852551e-26 -20.001259  1.891178
# 2698   3.315059e-18 -17.030884  1.957527
# 2699  8.347551e-112   7.202559  0.320537
#
# [200 rows x 8 columns]

# %%
df[df['dep_var'] == 'new_cases_1e6']
# Out:
#             dep_var                       bins_list  \
# 350   new_cases_1e6            [(0, 14), (15, 999)]
# 351   new_cases_1e6            [(0, 14), (15, 999)]
# 352   new_cases_1e6            [(0, 14), (15, 999)]
# 353   new_cases_1e6            [(0, 14), (15, 999)]
# 354   new_cases_1e6            [(0, 14), (15, 999)]
# ...             ...                             ...
# 2695  new_cases_1e6  [(0, 14), (15, 28), (29, 999)]
# 2696  new_cases_1e6  [(0, 14), (15, 28), (29, 999)]
# 2697  new_cases_1e6  [(0, 14), (15, 28), (29, 999)]
# 2698  new_cases_1e6  [(0, 14), (15, 28), (29, 999)]
# 2699  new_cases_1e6  [(0, 14), (15, 28), (29, 999)]
#
#                                        policy     bin  rsquared  \
# 350    outdoor and recreation - stop - county   const  0.000035
# 351    outdoor and recreation - stop - county    0-14  0.000035
# 352    outdoor and recreation - stop - county  15-999  0.000035
# 353   non-essential businesses - stop - state   const  0.024921
# 354   non-essential businesses - stop - state    0-14  0.024921
# ...                                       ...     ...       ...
# 2695            construction - start - county  29-999  0.000016
# 2696          executive order - start - state   const  0.000312
# 2697          executive order - start - state    0-14  0.000312
# 2698          executive order - start - state   15-28  0.000312
# 2699          executive order - start - state  29-999  0.000312
#
#             p_value      param   std_err
# 350    0.000000e+00  24.544402  0.039361
# 351    3.237806e-08  17.072292  3.088283
# 352    7.180054e-12   3.651913  0.532810
# 353    0.000000e+00   9.928571  0.074620
# 354    1.079129e-22   2.739895  0.279456
# ...             ...        ...       ...
# 2695   5.576166e-06   5.718120  1.258981
# 2696   0.000000e+00  24.472916  0.039563
# 2697   3.852551e-26 -20.001259  1.891178
# 2698   3.315059e-18 -17.030884  1.957527
# 2699  8.347551e-112   7.202559  0.320537
#
# [850 rows x 8 columns]

# %%
df[(df['bins_list'] == '[(0, 14), (15, 28), (29, 999)]') &\
   (df['dep_var'] == 'new_deaths_7day_1e6') &\
   (df['policy'] == 'outdoor and recreation - stop - county')]
# Out:
#                dep_var                       bins_list  \
# 0  new_deaths_7day_1e6  [(0, 14), (15, 28), (29, 999)]
# 1  new_deaths_7day_1e6  [(0, 14), (15, 28), (29, 999)]
# 2  new_deaths_7day_1e6  [(0, 14), (15, 28), (29, 999)]
# 3  new_deaths_7day_1e6  [(0, 14), (15, 28), (29, 999)]
#
#                                    policy     bin  rsquared       p_value  \
# 0  outdoor and recreation - stop - county   const  0.000026  0.000000e+00
# 1  outdoor and recreation - stop - county    0-14  0.000026  1.130057e-06
# 2  outdoor and recreation - stop - county   15-28  0.000026  6.960655e-09
# 3  outdoor and recreation - stop - county  29-999  0.000026  5.084651e-01
#
#       param   std_err
# 0  0.430151  0.000771
# 1  0.294389  0.060480
# 2  0.362587  0.062602
# 3  0.006996  0.010581

# %%
df['bins_list'][0]
# Out:
# '[(0, 14), (15, 28), (29, 999)]'

# %% [markdown]
# # 2. Visualize results - order by r-squared

# %%
import seaborn as sns

# %%
def show_heatmap_for_bins(df, dep_var, value='rsquared'):
    data = df[(df['dep_var']==dep_var)]
#     data = data[['policy', 'bin', value]]
#     data = data.set_index('policy')
#     data = data.pivot(columns='bin')

#     sns.heatmap(data)
    
    return data
    
data = show_heatmap_for_bins(df, 'new_cases_1e6')

# %%
data
# Out:
#             dep_var                       bins_list  \
# 350   new_cases_1e6            [(0, 14), (15, 999)]
# 351   new_cases_1e6            [(0, 14), (15, 999)]
# 352   new_cases_1e6            [(0, 14), (15, 999)]
# 353   new_cases_1e6            [(0, 14), (15, 999)]
# 354   new_cases_1e6            [(0, 14), (15, 999)]
# ...             ...                             ...
# 2695  new_cases_1e6  [(0, 14), (15, 28), (29, 999)]
# 2696  new_cases_1e6  [(0, 14), (15, 28), (29, 999)]
# 2697  new_cases_1e6  [(0, 14), (15, 28), (29, 999)]
# 2698  new_cases_1e6  [(0, 14), (15, 28), (29, 999)]
# 2699  new_cases_1e6  [(0, 14), (15, 28), (29, 999)]
#
#                                        policy     bin  rsquared  \
# 350    outdoor and recreation - stop - county   const  0.000035
# 351    outdoor and recreation - stop - county    0-14  0.000035
# 352    outdoor and recreation - stop - county  15-999  0.000035
# 353   non-essential businesses - stop - state   const  0.024921
# 354   non-essential businesses - stop - state    0-14  0.024921
# ...                                       ...     ...       ...
# 2695            construction - start - county  29-999  0.000016
# 2696          executive order - start - state   const  0.000312
# 2697          executive order - start - state    0-14  0.000312
# 2698          executive order - start - state   15-28  0.000312
# 2699          executive order - start - state  29-999  0.000312
#
#             p_value      param   std_err
# 350    0.000000e+00  24.544402  0.039361
# 351    3.237806e-08  17.072292  3.088283
# 352    7.180054e-12   3.651913  0.532810
# 353    0.000000e+00   9.928571  0.074620
# 354    1.079129e-22   2.739895  0.279456
# ...             ...        ...       ...
# 2695   5.576166e-06   5.718120  1.258981
# 2696   0.000000e+00  24.472916  0.039563
# 2697   3.852551e-26 -20.001259  1.891178
# 2698   3.315059e-18 -17.030884  1.957527
# 2699  8.347551e-112   7.202559  0.320537
#
# [850 rows x 8 columns]

# %%
data = data[['policy', 'bins_list', 'rsquared']]
data
# Out:
#                                        policy                       bins_list  \
# 350    outdoor and recreation - stop - county            [(0, 14), (15, 999)]
# 351    outdoor and recreation - stop - county            [(0, 14), (15, 999)]
# 352    outdoor and recreation - stop - county            [(0, 14), (15, 999)]
# 353   non-essential businesses - stop - state            [(0, 14), (15, 999)]
# 354   non-essential businesses - stop - state            [(0, 14), (15, 999)]
# ...                                       ...                             ...
# 2695            construction - start - county  [(0, 14), (15, 28), (29, 999)]
# 2696          executive order - start - state  [(0, 14), (15, 28), (29, 999)]
# 2697          executive order - start - state  [(0, 14), (15, 28), (29, 999)]
# 2698          executive order - start - state  [(0, 14), (15, 28), (29, 999)]
# 2699          executive order - start - state  [(0, 14), (15, 28), (29, 999)]
#
#       rsquared
# 350   0.000035
# 351   0.000035
# 352   0.000035
# 353   0.024921
# 354   0.024921
# ...        ...
# 2695  0.000016
# 2696  0.000312
# 2697  0.000312
# 2698  0.000312
# 2699  0.000312
#
# [850 rows x 3 columns]

# %%
data
# Out:
#                                        policy                       bins_list  \
# 350    outdoor and recreation - stop - county            [(0, 14), (15, 999)]
# 351    outdoor and recreation - stop - county            [(0, 14), (15, 999)]
# 352    outdoor and recreation - stop - county            [(0, 14), (15, 999)]
# 353   non-essential businesses - stop - state            [(0, 14), (15, 999)]
# 354   non-essential businesses - stop - state            [(0, 14), (15, 999)]
# ...                                       ...                             ...
# 2695            construction - start - county  [(0, 14), (15, 28), (29, 999)]
# 2696          executive order - start - state  [(0, 14), (15, 28), (29, 999)]
# 2697          executive order - start - state  [(0, 14), (15, 28), (29, 999)]
# 2698          executive order - start - state  [(0, 14), (15, 28), (29, 999)]
# 2699          executive order - start - state  [(0, 14), (15, 28), (29, 999)]
#
#       rsquared
# 350   0.000035
# 351   0.000035
# 352   0.000035
# 353   0.024921
# 354   0.024921
# ...        ...
# 2695  0.000016
# 2696  0.000312
# 2697  0.000312
# 2698  0.000312
# 2699  0.000312
#
# [850 rows x 3 columns]

# %%
data = data.drop_duplicates()
data2 = data.set_index('policy')
data2 = data2.pivot(columns='bins_list')

# %%
data2
# Out:
#                                                                 rsquared  \
# bins_list                                 [(0, 14), (15, 28), (29, 999)]
# policy
# childcare - start - county                                      0.000120
# childcare - start - state                                       0.031380
# childcare - stop - county                                       0.000014
# childcare - stop - state                                        0.007980
# construction - start - county                                   0.000016
# education - start - state                                       0.000747
# entertainment - start - county                                  0.000160
# entertainment - start - state                                   0.028513
# entertainment - stop - county                                   0.000053
# entertainment - stop - state                                    0.031150
# executive order - start - state                                 0.000312
# executive order - stop - state                                  0.000402
# gatherings - start - state                                      0.001157
# gyms - start - state                                            0.021124
# gyms - stop - state                                             0.029423
# houses of worship - start - county                              0.000061
# houses of worship - start - state                               0.013174
# houses of worship - stop - county                               0.000026
# houses of worship - stop - state                                0.007123
# housing - start - state                                         0.012306
# manufacturing - start - county                                  0.000080
# manufacturing - start - state                                   0.006018
# manufacturing - stop - county                                   0.000027
# manufacturing - stop - state                                    0.004572
# mask mandate - start - county                                   0.000194
# mask mandate - start - state                                    0.023731
# mask mandate - stop - county                                    0.000005
# mask mandate - stop - state                                     0.006995
# medical - start - county                                        0.000187
# medical - start - state                                         0.025211
# non-essential businesses - start - county                       0.000076
# non-essential businesses - start - state                        0.027780
# non-essential businesses - stop - county                        0.000019
# non-essential businesses - stop - state                         0.026928
# nursing homes - start - state                                   0.006044
# outdoor and recreation - start - county                         0.000091
# outdoor and recreation - start - state                          0.021022
# outdoor and recreation - stop - county                          0.000035
# outdoor and recreation - stop - state                           0.014655
# personal care - start - county                                  0.000004
# personal care - start - state                                   0.010367
# personal care - stop - county                                   0.000003
# personal care - stop - state                                    0.004481
# shelter in place - start - county                               0.000717
# shelter in place - start - state                                0.012886
# shelter in place - stop - county                                0.000752
# shelter in place - stop - state                                 0.019945
# state of emergency - start - state                              0.020672
# travel - start - state                                          0.000671
# wholesale trade - start - county                                0.000018
#
#                                                                 \
# bins_list                                 [(0, 14), (15, 999)]
# policy
# childcare - start - county                            0.000106
# childcare - start - state                             0.028484
# childcare - stop - county                             0.000014
# childcare - stop - state                              0.007069
# construction - start - county                         0.000011
# education - start - state                             0.000518
# entertainment - start - county                        0.000159
# entertainment - start - state                         0.024964
# entertainment - stop - county                         0.000051
# entertainment - stop - state                          0.029081
# executive order - start - state                       0.000245
# executive order - stop - state                        0.000314
# gatherings - start - state                            0.000883
# gyms - start - state                                  0.018069
# gyms - stop - state                                   0.026217
# houses of worship - start - county                    0.000060
# houses of worship - start - state                     0.011058
# houses of worship - stop - county                     0.000026
# houses of worship - stop - state                      0.006439
# housing - start - state                               0.008275
# manufacturing - start - county                        0.000079
# manufacturing - start - state                         0.005327
# manufacturing - stop - county                         0.000026
# manufacturing - stop - state                          0.004170
# mask mandate - start - county                         0.000183
# mask mandate - start - state                          0.021818
# mask mandate - stop - county                          0.000004
# mask mandate - stop - state                           0.006654
# medical - start - county                              0.000157
# medical - start - state                               0.022154
# non-essential businesses - start - county             0.000075
# non-essential businesses - start - state              0.024890
# non-essential businesses - stop - county              0.000017
# non-essential businesses - stop - state               0.024921
# nursing homes - start - state                         0.004114
# outdoor and recreation - start - county               0.000086
# outdoor and recreation - start - state                0.017923
# outdoor and recreation - stop - county                0.000035
# outdoor and recreation - stop - state                 0.013712
# personal care - start - county                        0.000002
# personal care - start - state                         0.008291
# personal care - stop - county                         0.000002
# personal care - stop - state                          0.003864
# shelter in place - start - county                     0.000424
# shelter in place - start - state                      0.010502
# shelter in place - stop - county                      0.000414
# shelter in place - stop - state                       0.016917
# state of emergency - start - state                    0.017277
# travel - start - state                                0.000492
# wholesale trade - start - county                      0.000012
#
#                                                                                             \
# bins_list                                 [(0, 7), (8, 14), (15, 28), (29, 60), (61, 999)]
# policy
# childcare - start - county                                                        0.000206
# childcare - start - state                                                         0.036688
# childcare - stop - county                                                         0.000019
# childcare - stop - state                                                          0.009460
# construction - start - county                                                     0.000028
# education - start - state                                                         0.001172
# entertainment - start - county                                                    0.000175
# entertainment - start - state                                                     0.034995
# entertainment - stop - county                                                     0.000053
# entertainment - stop - state                                                      0.034114
# executive order - start - state                                                   0.000505
# executive order - stop - state                                                    0.000642
# gatherings - start - state                                                        0.001787
# gyms - start - state                                                              0.027727
# gyms - stop - state                                                               0.034303
# houses of worship - start - county                                                0.000062
# houses of worship - start - state                                                 0.016210
# houses of worship - stop - county                                                 0.000028
# houses of worship - stop - state                                                  0.008037
# housing - start - state                                                           0.019443
# manufacturing - start - county                                                    0.000121
# manufacturing - start - state                                                     0.007396
# manufacturing - stop - county                                                     0.000033
# manufacturing - stop - state                                                      0.005096
# mask mandate - start - county                                                     0.000194
# mask mandate - start - state                                                      0.027667
# mask mandate - stop - county                                                      0.000011
# mask mandate - stop - state                                                       0.007658
# medical - start - county                                                          0.000259
# medical - start - state                                                           0.032329
# non-essential businesses - start - county                                         0.000090
# non-essential businesses - start - state                                          0.033591
# non-essential businesses - stop - county                                          0.000027
# non-essential businesses - stop - state                                           0.030232
# nursing homes - start - state                                                     0.010462
# outdoor and recreation - start - county                                           0.000093
# outdoor and recreation - start - state                                            0.027261
# outdoor and recreation - stop - county                                            0.000041
# outdoor and recreation - stop - state                                             0.016097
# personal care - start - county                                                    0.000005
# personal care - start - state                                                     0.013752
# personal care - stop - county                                                     0.000003
# personal care - stop - state                                                      0.005426
# shelter in place - start - county                                                 0.001434
# shelter in place - start - state                                                  0.018620
# shelter in place - stop - county                                                  0.001450
# shelter in place - stop - state                                                   0.025470
# state of emergency - start - state                                                0.027592
# travel - start - state                                                            0.001101
# wholesale trade - start - county                                                  0.000033
#
#
# bins_list                                 [(0, 7), (8, 14), (15, 999)]
# policy
# childcare - start - county                                    0.000107
# childcare - start - state                                     0.028484
# childcare - stop - county                                     0.000014
# childcare - stop - state                                      0.007067
# construction - start - county                                 0.000011
# education - start - state                                     0.000516
# entertainment - start - county                                0.000160
# entertainment - start - state                                 0.024942
# entertainment - stop - county                                 0.000051
# entertainment - stop - state                                  0.029084
# executive order - start - state                               0.000245
# executive order - stop - state                                0.000314
# gatherings - start - state                                    0.000883
# gyms - start - state                                          0.018071
# gyms - stop - state                                           0.026217
# houses of worship - start - county                            0.000061
# houses of worship - start - state                             0.011058
# houses of worship - stop - county                             0.000026
# houses of worship - stop - state                              0.006439
# housing - start - state                                       0.008276
# manufacturing - start - county                                0.000080
# manufacturing - start - state                                 0.005334
# manufacturing - stop - county                                 0.000027
# manufacturing - stop - state                                  0.004173
# mask mandate - start - county                                 0.000183
# mask mandate - start - state                                  0.021831
# mask mandate - stop - county                                  0.000004
# mask mandate - stop - state                                   0.006654
# medical - start - county                                      0.000157
# medical - start - state                                       0.021502
# non-essential businesses - start - county                     0.000076
# non-essential businesses - start - state                      0.024891
# non-essential businesses - stop - county                      0.000018
# non-essential businesses - stop - state                       0.024922
# nursing homes - start - state                                 0.004116
# outdoor and recreation - start - county                       0.000087
# outdoor and recreation - start - state                        0.017923
# outdoor and recreation - stop - county                        0.000035
# outdoor and recreation - stop - state                         0.013712
# personal care - start - county                                0.000002
# personal care - start - state                                 0.008292
# personal care - stop - county                                 0.000002
# personal care - stop - state                                  0.003868
# shelter in place - start - county                             0.000425
# shelter in place - start - state                              0.010505
# shelter in place - stop - county                              0.000414
# shelter in place - stop - state                               0.016918
# state of emergency - start - state                            0.017278
# travel - start - state                                        0.000492
# wholesale trade - start - county                              0.000012

# %%
data2.columns.values
# Out:
# array([('rsquared', '[(0, 14), (15, 28), (29, 999)]'),
#        ('rsquared', '[(0, 14), (15, 999)]'),
#        ('rsquared', '[(0, 7), (8, 14), (15, 28), (29, 60), (61, 999)]'),
#        ('rsquared', '[(0, 7), (8, 14), (15, 999)]')], dtype=object)

# %%
col_tuples = data2.columns.values
new_cols = []
bins_ids = {}
for i, col in enumerate(col_tuples):
    new_cols.append(f"bin_set_{i}")
    bins_ids[f"bin_set_{i}"] = col[1]
    
data2.columns = new_cols

# %%
bins_ids
# Out:
# {'bin_set_0': '[(0, 14), (15, 28), (29, 999)]',
#  'bin_set_1': '[(0, 14), (15, 999)]',
#  'bin_set_2': '[(0, 7), (8, 14), (15, 28), (29, 60), (61, 999)]',
#  'bin_set_3': '[(0, 7), (8, 14), (15, 999)]'}

# %%
new_cols
# Out:
# ['bin_set_0', 'bin_set_1', 'bin_set_2', 'bin_set_3']

# %%
data2
# Out:
#                                            bin_set_0  bin_set_1  bin_set_2  \
# policy
# childcare - start - county                  0.000120   0.000106   0.000206
# childcare - start - state                   0.031380   0.028484   0.036688
# childcare - stop - county                   0.000014   0.000014   0.000019
# childcare - stop - state                    0.007980   0.007069   0.009460
# construction - start - county               0.000016   0.000011   0.000028
# education - start - state                   0.000747   0.000518   0.001172
# entertainment - start - county              0.000160   0.000159   0.000175
# entertainment - start - state               0.028513   0.024964   0.034995
# entertainment - stop - county               0.000053   0.000051   0.000053
# entertainment - stop - state                0.031150   0.029081   0.034114
# executive order - start - state             0.000312   0.000245   0.000505
# executive order - stop - state              0.000402   0.000314   0.000642
# gatherings - start - state                  0.001157   0.000883   0.001787
# gyms - start - state                        0.021124   0.018069   0.027727
# gyms - stop - state                         0.029423   0.026217   0.034303
# houses of worship - start - county          0.000061   0.000060   0.000062
# houses of worship - start - state           0.013174   0.011058   0.016210
# houses of worship - stop - county           0.000026   0.000026   0.000028
# houses of worship - stop - state            0.007123   0.006439   0.008037
# housing - start - state                     0.012306   0.008275   0.019443
# manufacturing - start - county              0.000080   0.000079   0.000121
# manufacturing - start - state               0.006018   0.005327   0.007396
# manufacturing - stop - county               0.000027   0.000026   0.000033
# manufacturing - stop - state                0.004572   0.004170   0.005096
# mask mandate - start - county               0.000194   0.000183   0.000194
# mask mandate - start - state                0.023731   0.021818   0.027667
# mask mandate - stop - county                0.000005   0.000004   0.000011
# mask mandate - stop - state                 0.006995   0.006654   0.007658
# medical - start - county                    0.000187   0.000157   0.000259
# medical - start - state                     0.025211   0.022154   0.032329
# non-essential businesses - start - county   0.000076   0.000075   0.000090
# non-essential businesses - start - state    0.027780   0.024890   0.033591
# non-essential businesses - stop - county    0.000019   0.000017   0.000027
# non-essential businesses - stop - state     0.026928   0.024921   0.030232
# nursing homes - start - state               0.006044   0.004114   0.010462
# outdoor and recreation - start - county     0.000091   0.000086   0.000093
# outdoor and recreation - start - state      0.021022   0.017923   0.027261
# outdoor and recreation - stop - county      0.000035   0.000035   0.000041
# outdoor and recreation - stop - state       0.014655   0.013712   0.016097
# personal care - start - county              0.000004   0.000002   0.000005
# personal care - start - state               0.010367   0.008291   0.013752
# personal care - stop - county               0.000003   0.000002   0.000003
# personal care - stop - state                0.004481   0.003864   0.005426
# shelter in place - start - county           0.000717   0.000424   0.001434
# shelter in place - start - state            0.012886   0.010502   0.018620
# shelter in place - stop - county            0.000752   0.000414   0.001450
# shelter in place - stop - state             0.019945   0.016917   0.025470
# state of emergency - start - state          0.020672   0.017277   0.027592
# travel - start - state                      0.000671   0.000492   0.001101
# wholesale trade - start - county            0.000018   0.000012   0.000033
#
#                                            bin_set_3
# policy
# childcare - start - county                  0.000107
# childcare - start - state                   0.028484
# childcare - stop - county                   0.000014
# childcare - stop - state                    0.007067
# construction - start - county               0.000011
# education - start - state                   0.000516
# entertainment - start - county              0.000160
# entertainment - start - state               0.024942
# entertainment - stop - county               0.000051
# entertainment - stop - state                0.029084
# executive order - start - state             0.000245
# executive order - stop - state              0.000314
# gatherings - start - state                  0.000883
# gyms - start - state                        0.018071
# gyms - stop - state                         0.026217
# houses of worship - start - county          0.000061
# houses of worship - start - state           0.011058
# houses of worship - stop - county           0.000026
# houses of worship - stop - state            0.006439
# housing - start - state                     0.008276
# manufacturing - start - county              0.000080
# manufacturing - start - state               0.005334
# manufacturing - stop - county               0.000027
# manufacturing - stop - state                0.004173
# mask mandate - start - county               0.000183
# mask mandate - start - state                0.021831
# mask mandate - stop - county                0.000004
# mask mandate - stop - state                 0.006654
# medical - start - county                    0.000157
# medical - start - state                     0.021502
# non-essential businesses - start - county   0.000076
# non-essential businesses - start - state    0.024891
# non-essential businesses - stop - county    0.000018
# non-essential businesses - stop - state     0.024922
# nursing homes - start - state               0.004116
# outdoor and recreation - start - county     0.000087
# outdoor and recreation - start - state      0.017923
# outdoor and recreation - stop - county      0.000035
# outdoor and recreation - stop - state       0.013712
# personal care - start - county              0.000002
# personal care - start - state               0.008292
# personal care - stop - county               0.000002
# personal care - stop - state                0.003868
# shelter in place - start - county           0.000425
# shelter in place - start - state            0.010505
# shelter in place - stop - county            0.000414
# shelter in place - stop - state             0.016918
# state of emergency - start - state          0.017278
# travel - start - state                      0.000492
# wholesale trade - start - county            0.000012

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=[5, 10])

sns.heatmap(data2, ax=ax)
# Out:
# <AxesSubplot:ylabel='policy'>

# %% [markdown]
# Sorting

# %%
# max rsquared
maxes = data2.idxmax().values
max_vals = np.array([data2.loc[m, :][i] for i, m in enumerate(maxes)])
max_col = np.argmax(max_vals)
print(max_col)
# Out:
# 2

# %%
max_vals
# Out:
# array([0.03138017, 0.02908139, 0.0366881 , 0.02908388])

# %%
maxes
# Out:
# array(['childcare - start - state', 'entertainment - stop - state',
#        'childcare - start - state', 'entertainment - stop - state'],
#       dtype=object)

# %%
for i, m in enumerate(maxes):
    print(data2.loc[m, :][i])
    break
# Out:
# 0.03138017193708875

# %%
maxes
# Out:
# array(['childcare - start - state', 'entertainment - stop - state',
#        'childcare - start - state', 'entertainment - stop - state'],
#       dtype=object)

# %%
data3 = data2.sort_values(by=data2.columns[max_col], ascending=False)
fig, ax = plt.subplots(figsize=[5, 10])

sns.heatmap(data3, ax=ax)
# Out:
# <AxesSubplot:ylabel='policy'>

# %% [markdown]
# Questions:
#
# - Which set of bins provides the best model?
# - Which set of policies have the best r squared?

# %% [markdown]
# # Wrap everything into functions

# %%
def collect_all_regression_results_to_df(regression_results_path):
    """Collect the results from every regression analysis found in the passed folder
    
    There should be a set of json files with the name format <dep_var>_bins=<bin1>_<bin2>....json
    
    Parameters
    ----------
    regression_results_path
        path to folder with results json files
        
    Returns
    ---------
    pandas dataframe with columns:
        dep_var, bins_list, policy, bin, rsquared, p_value, param, and std_err
    """
    results_files = os.listdir(regression_results_path)

    cols = ['dep_var', 'policy', 'bins_list', 'bin', 'r_squared', 'p_value', 'param', 'std_err']
    all_data = dict()
    pk = 0
    for r in results_files:
        if 'bins' not in r:
            continue
        dep_var = r.split('bins')[0][:-1]
        bins_str = r.split('=')[1].split('.')[0]
        bins_list = [(int(e.split('-')[0]), int(e.split('-')[1]))
                      for e in bins_str.split('_')]
        with open(regression_results_path+r, "r") as f:
            data = json.load(f)

        for policy in data:
            r2 = data[policy]['r_squared']

            for b in data[policy]['p_values']:
                all_data[pk] = {
                    'dep_var': dep_var,
                    'bins_list': str(bins_list),
                    'policy': policy,
                    'bin': b,
                    'rsquared': r2,
                    'p_value': data[policy]['p_values'][b],
                    'param': data[policy]['params'][b],
                    'std_err': data[policy]['std_err'][b]
                }
                pk += 1

        df = pd.DataFrame.from_dict(all_data, orient='index')
    return df

# %%
df = collect_all_regression_results_to_df("./data/regression_results/")

# %%
def plot_rsquared_heatmap(data,
                          dep_var,
                          sort_values = True,
                          ax = None):
    """Plots a heatmap of r-squared values for the given dependent variable. Generates a column
    for each set of bins and a row for each policy, where the color is the r-squared value.
    
    Parameters
    ----------
    data
        pandas dataframe: input data, return value of collect_all_regression_results_to_df
    
    dep_var
        string: dependent variable
        
    sort_values
        boolean: if true, sorts the plot such that the column containing the highest r-squared
        value appears in descending order
    
    ax:
        matlotlib axis handle
        
    Returns
    ---------
    ax
        axis handle containing the plot

    bin_ids
        dictionary of bins - used for reference on x-axis
    """
    
    ### data preparation
    data = data[(data['dep_var']==dep_var)]
    data = data[['policy', 'bins_list', 'rsquared']]
    data = data.drop_duplicates()
    data = data.set_index('policy')
    data = data.pivot(columns='bins_list')
    
    ### rename columns
    # generate a set of bin ids
    # this cleans up the plot a bit
    # bin ids will also be returned for reference
    col_tuples = data.columns.values
    new_cols = []
    bins_ids = {}
    for i, col in enumerate(col_tuples):
        new_cols.append(f"bin_set_{i}")
        bins_ids[f"bin_set_{i}"] = col[1]

    data.columns = new_cols
    
    ### optionally sort the dataframe such that the
    # bin containing the maximum r-squared appears sorted
    # in descending order
    if sort_values:
        maxes = data.idxmax().values
        max_vals = np.array([data.loc[m, :][i] for i, m in enumerate(maxes)])
        max_col = np.argmax(max_vals)
        data = data.sort_values(by=data.columns[max_col], ascending=False)

    if ax is None:
        fig, ax = plt.subplots(figsize=[5, 10])

    ax = sns.heatmap(data, ax=ax)

    return ax, bin_ids
