# %% [markdown]
# # CovidDataClass tests
#
# Run the functions in the CovidDataClass class to ensure that all image visualization and processing functions are working properly

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.CovidDataClass import CovidDataClass as cd
from src.cfg import *

# %%
data = cd(load_local=True, load_clean=True)
# Out:
# /home/alex/anaconda3/envs/covid_project/lib/python3.9/site-packages/numpy/lib/arraysetops.py:583: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
data.data.head()
# Out:
#             uid location_type  fips_code   county    state        date  \
# 38400  84001001        county       1001  autauga  Alabama  2020-01-22
# 38401  84001001        county       1001  autauga  Alabama  2020-01-23
# 38402  84001001        county       1001  autauga  Alabama  2020-01-24
# 38403  84001001        county       1001  autauga  Alabama  2020-01-25
# 38404  84001001        county       1001  autauga  Alabama  2020-01-26
#
#           full_loc_name  total_population  cumulative_cases  \
# 38400  Autauga, Alabama             55200                 0
# 38401  Autauga, Alabama             55200                 0
# 38402  Autauga, Alabama             55200                 0
# 38403  Autauga, Alabama             55200                 0
# 38404  Autauga, Alabama             55200                 0
#
#        cumulative_cases_1e6  cumulative_deaths  cumulative_deaths_1e6  \
# 38400                   0.0                  0                    0.0
# ...

# %%
data.policies.head()
# Out:
#       state     county  fips_code policy_level        date  \
# 0  New York      bronx      36005       county  2020-06-08
# 1      Utah      weber      49057       county  2020-11-24
# 2  Delaware  statewide         10        state  2020-03-27
# 3   Florida  statewide         12        state  2020-03-18
# 4  Michigan      delta      26041       county  2020-07-31
#
#                            policy_type start_stop  \
# 0             non-essential businesses      start
# 1                        entertainment      start
# 2         modify medicaid requirements      start
# 3  expand medicaid telehealth coverage      start
# 4                        entertainment      start
#
#                                             comments  \
# 0  Policy_Details: Construction\nAgriculture, For...
# 1  Policy_Details: - Social gatherings of 10 or f...
# 2  Other measures and details for this policy inc...
# 3  Other measures and details for this policy inc...
# ...

# %%
data.get_cases()
# Out:
#             new_cases_1e6  new_deaths_1e6  new_cases_7day_1e6  \
# date
# 2020-01-22           0.00            0.00            0.000000
# 2020-01-23           0.00            0.00            0.000000
# 2020-01-24           0.00            0.00            0.000000
# 2020-01-25           0.00            0.00            0.000000
# 2020-01-26           0.03            0.00            0.000000
# ...                   ...             ...                 ...
# 2021-05-11           2.62            0.28            1.981871
# 2021-05-12           1.80            0.19            1.955008
# 2021-05-13           1.36            0.09            1.869045
# 2021-05-14           4.77            0.06            2.297908
# 2021-05-15           1.90            0.06            2.207838
#
#             new_deaths_7day_1e6
# date
# 2020-01-22             0.000000
# 2020-01-23             0.000000
# 2020-01-24             0.000000
# 2020-01-25             0.000000
# 2020-01-26             0.000000
# ...

# %%
data.get_policy_data().head()
# Out:
#           state     county  fips_code policy_level        date  \
# 30   California  statewide          6        state  2020-03-19
# 309  California  statewide          6        state  2020-03-19
# 436  California  statewide          6        state  2020-01-25
# 547  California  statewide          6        state  2020-04-24
# 563  California  statewide          6        state  2020-09-02
#
#                              policy_type start_stop  \
# 30              non-essential businesses      start
# 309                     shelter in place      start
# 436                     shelter in place       stop
# 547  resumed elective medical procedures      start
# 563        stop enforcement of evictions      start
#
#                                               comments  \
# 30   Other measures and details for this policy inc...
# 309                                 State Policy Start
# 436  Other measures and details for this policy inc...
# ...

# %%
data.plot_cases();

# %%
data.plot_cases_and_policies()
# Out:
# (<Figure size 720x360 with 2 Axes>,
#  array([<AxesSubplot:title={'center':'New COVID-19 cases and deaths per 100,000 in orange County, California'}, xlabel='date', ylabel='cases per 100,000'>,
#         <AxesSubplot:xlabel='date', ylabel='deaths per 100,000'>],
#        dtype=object))

# %% [markdown]
# # Data preprocessing for ML

# %%
policy_data = data.prep_policy_data()

# %%
prepped_data = data.join_policies(data.data, policy_data)
# Out:
# data shaped
# bins: [(0, 6), (7, 13), (14, 999)]
# time elapsed: 90.97609996795654

# %%
prepped_data
# Out:
#             info                                                      \
#            state   county          full_loc       date new_cases_1e6
# 38400    Alabama  autauga  Autauga, Alabama 2020-01-22           0.0
# 38401    Alabama  autauga  Autauga, Alabama 2020-01-23           0.0
# 38402    Alabama  autauga  Autauga, Alabama 2020-01-24           0.0
# 38403    Alabama  autauga  Autauga, Alabama 2020-01-25           0.0
# 38404    Alabama  autauga  Autauga, Alabama 2020-01-26           0.0
# ...          ...      ...               ...        ...           ...
# 1547515  Wyoming   weston   Weston, Wyoming 2021-05-11           0.0
# 1547516  Wyoming   weston   Weston, Wyoming 2021-05-12           0.0
# 1547517  Wyoming   weston   Weston, Wyoming 2021-05-13           0.0
# 1547518  Wyoming   weston   Weston, Wyoming 2021-05-14           0.0
# 1547519  Wyoming   weston   Weston, Wyoming 2021-05-15           0.0
#
#         non-essential businesses - start - county              \
# ...

# %% [markdown]
# TODO: Instead of a large dataframe, use dictionary for processing all the data
#
# proc_data = {
#
#     'bins': [bins_arr],
#     'row_id': {
#         'state': state,
#         'county': county,
#         'full_loc': full_loc,
#         'date': date,
#         'new_cases_1e6': new_cases_1e6,
#         'policies': {
#             'policy_name': [arr],
#             'policy_name': [arr],
#             .
#             .
#             .
#
#         }
#     }
# }

# %% [markdown]
# Set aside some counties for the test set

# %%
locations = data.data['full_loc_name'].unique()

# %%
type(locations)
# Out:
# numpy.ndarray

# %%
import numpy as np
np.random.shuffle(locations)

# %%
locations
# Out:
# array(['Lawrence, Illinois', 'Gilpin, Colorado', 'Jefferson, Colorado',
#        ..., 'Grant, Oregon', 'Alcona, Michigan', 'Clark, Ohio'],
#       dtype=object)

# %%
len(locations)
# Out:
# 3143

# %%
test_locs = list(locations[:int(len(locations)*0.2)])
train_locs = list(locations[int(len(locations)*0.2):])

# %%
len(test_locs)
# Out:
# 628

# %%
len(train_locs)
# Out:
# 2515

# %%
# import json

# with open(ROOT_DIR + "test_locs.json", 'wb') as f:
#   json.dump(test_locs, f)
  
# with open(ROOT_DIR + "train_locs.json", 'wb') as f:
#   json.dump(train_locs, f)

np.savetxt(ROOT_DIR + "test_locs.txt", test_locs, delimiter=";", fmt='%s')
np.savetxt(ROOT_DIR + "train_locs.txt", train_locs, delimiter=";", fmt='%s')
