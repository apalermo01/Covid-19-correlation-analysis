# %% [markdown]
# # TODO: make this into a streamlit app

# %% [markdown]
# # 0. Imports

# %%
from covid_project.plotting_funcs import plot_cases, plot_cases_and_policies
from covid_project.data_utils import clean_covid_data, clean_policy_data

# %% [markdown]
# # 1. Plot cases for some locations

# %%
# get the data
case_data = clean_covid_data()
policy_data = clean_policy_data()

# %%
#plot_cases(case_data=case_data)

# %%
# plot_cases(case_data=case_data,
#            level='state',
#            state='North Carolina',
#            )

# %% [markdown]
# # 2. Plot case and policy overlay

# %%
plot_cases_and_policies(
    county='mecklenburg',
    state='North Carolina',
    case_data=case_data,
    policy_data=policy_data,
)
# Out:
# days_serial=18331; cent_coord=0.125
# days_serial=18347; cent_coord=0.12882263532164795
# days_serial=18351; cent_coord=0.13090156083888263
# days_serial=18381; cent_coord=0.130397267025296
# days_serial=18390; cent_coord=0.1322041973369519
# days_serial=18439; cent_coord=0.16446576920730613
# days_serial=18439; cent_coord=0.16446576920730613
# days_serial=18331; cent_coord=0.12499999999999997
# days_serial=18347; cent_coord=0.12499999999999997
# days_serial=18351; cent_coord=0.13187307273885593
# days_serial=18381; cent_coord=0.17409337670611408
# days_serial=18390; cent_coord=0.18833045595088718
# days_serial=18439; cent_coord=0.21631368067337226
# days_serial=18439; cent_coord=0.21631368067337226
# (<Figure size 720x360 with 2 Axes>,
#  array([<AxesSubplot:title={'center':'New COVID-19 cases and deaths per 100,000 in mecklenburg County, North Carolina'}, xlabel='date', ylabel='cases per 100,000'>,
#         <AxesSubplot:xlabel='date', ylabel='deaths per 100,000'>],
#        dtype=object))
