# %% [markdown]
# # CovidDataClass tests
#
# Run the functions in the CovidDataClass class to ensure that all image visualization and processing functions are working properly

# %%
from src.CovidDataClass import CovidDataClass as cd
from src.cfg import *
import os
import numpy as np
import pandas as pd
import numpy as np

# sklearn modules
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_squared_error, explained_variance_score
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-72464464617b> in <module>
# ----> 1 from src.CovidDataClass import CovidDataClass as cd
#       2 from src.cfg import *
#       3 import os
#       4 import numpy as np
#       5 import pandas as pd
#
# ModuleNotFoundError: No module named 'src'

# %%
data = cd(load_local=True, load_clean=True)
# Out:
# /home/alex/anaconda3/envs/covid_project/lib/python3.9/site-packages/numpy/lib/arraysetops.py:583: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
models_dict = {
  'OLS': LinearRegression(),
  'Ridge': Ridge(),
}

metrics_dict = {
  'R^2': r2_score,
  'MSE': mean_squared_error,
}

bins_dict = {
  1: [(0, 14), (14, 999)],
  2: [(0, 21), (22, 999)]
}

results = data.run_batch(
  bins_dict=bins_dict,
  models_dict=models_dict,
  metrics_dict=metrics_dict,
  K=10,
  verbose=True,
  save_output=True,
  output_json=True,
  filename=RESULTS_DIR + "test_run_524.txt",
  json_file=RESULTS_DIR + "test_run_524.json",
)
# Out:
# bins: [(0, 14), (14, 999)]
# loaded data from csv
# running model: OLS
# number of cross-validation folds: 10
# num counties in validation set: 251
# fold: 0, scores: ['R^2: -4.023151388237151e+19', 'MSE: 8.224683050652088e+22']
# fold: 1, scores: ['R^2: 0.05737500707048737', 'MSE: 4005.517848246679']
# fold: 2, scores: ['R^2: 0.10279373786333623', 'MSE: 2088.1549239243564']
# fold: 3, scores: ['R^2: 0.08857410808447364', 'MSE: 2489.211104433162']
# fold: 4, scores: ['R^2: 0.08277868072105665', 'MSE: 2941.598449022863']
# fold: 5, scores: ['R^2: 0.11955049391771322', 'MSE: 1911.8802047372476']
# fold: 6, scores: ['R^2: 0.09437781355636143', 'MSE: 2428.79949482009']
# fold: 7, scores: ['R^2: 0.08769647856317053', 'MSE: 2608.6655769617955']
# fold: 8, scores: ['R^2: 0.11775045963131314', 'MSE: 1873.455372171447']
# fold: 9, scores: ['R^2: 0.0835696267085484', 'MSE: 2420.5365915983543']
# running model: Ridge
# number of cross-validation folds: 10
# num counties in validation set: 251
# ...

# %%
results
# Out:
# {1: {'OLS': {'params': {'copy_X': True,
#     'fit_intercept': True,
#     'n_jobs': None,
#     'normalize': False,
#     'positive': False},
#    'scores': {'R^2': [0.07542561531866421,
#      0.06104895560991552,
#      0.09077763465313415,
#      -3.347298791900865e+17,
#      0.10563354306230288,
#      0.08910667169649611,
#      0.10122814977105332,
#      0.10881331751005974,
#      0.12485152288517753,
#      0.08351110081039437],
#     'MSE': [3184.217145662261,
#      3544.9437280928796,
#      2360.01663299304,
#      7.307520498431437e+20,
#      1989.5062957487198,
#      2741.606402461975,
#      2120.83935918702,
#      2050.432974138469,
#      1696.5648214365701,
#      2932.6897316230156]}},
#   'Ridge': {'params': {'alpha': 1.0,
#     'copy_X': True,
#     'fit_intercept': True,
#     'max_iter': None,
#     'normalize': False,
#     'random_state': None,
#     'solver': 'auto',
#     'tol': 0.001},
#    'scores': {'R^2': [0.1025268536592453,
# ...
