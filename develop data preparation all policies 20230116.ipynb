# %% [markdown]
# # Develop data preparation all policies 20230116
#
# In the next version of the project, we will try modifying the data preprocessing steps.
#
# In the last version, we got the preprocessing pipeline working with one kind of policy, now we want to work with an arbitrary set of policies

# %%
from covid_project.data_utils import clean_covid_data, clean_policy_data, \
    prep_policy_data, prepare_new_df, prepare_data, load_policy_data, prepare_new_df, get_date_range

import os
import pandas as pd
from tabulate import tabulate
from sodapy import Socrata
from tqdm import tqdm
import numpy as np
from datetime import timedelta
from datetime import datetime
import us
import re
#from tqdm import tqdm
from tqdm.notebook import tqdm
from typing import Tuple, Union, List

# %%
case_data = clean_covid_data()

# %%
policy_data = clean_policy_data()

# %%
policy_dict = {
    'aca special enrollment period'            : 'medical', 
    'agriculture'                              : 'agriculture',
    'allow audio only telehealth'              : 'medical', 
    'alternative care facilities'              : 'medical', 
    'bars'                                     : 'entertainement', 
    'childcare (k-12)'                         : 'childcare', 
    'colleges & universities'                  : 'education',
    'construction'                             : 'construction', 
    'day camps/overnight camps'                : 'camps', 
    'day care'                                 : 'childcare',
    'education'                                : 'education', 
    'election'                                 : 'election', 
    'entertainment'                            : 'entertainment', 
    'executive order'                          : 'executive order',
    'expand medicaid telehealth coverage'      : 'medical', 
    'food and drink'                           : 'entertainment',
    'froze mortgage payments'                  : 'housing', 
    'gatherings'                               : 'gatherings', 
    'grace period / security deposit for rent' : 'housing', 
    'graduation'                               : 'graduation',
    'graduation ceremony guidelines'           : 'graduation', 
    'gyms'                                     : 'gyms', 
    'health risk status'                       : 'medical',
    'higher education'                         : 'education', 
    'houses of worship'                        : 'houses of worship', 
    'libraries'                                : 'education',
    'mandate face masks in businesses'         : 'mask mandate',
    'mandate face masks in public spaces'      : 'mask mandate', 
    'manufacturing'                            : 'manufacturing',
    'mask requirement' : 'mask mandate', 
    'medical' : 'medical', 
    'modify medicaid requirements' : 'medical',
    'museums' : 'education', 
    'non-essential businesses' : 'non-essential businesses', 
    'nursing home visitations' : 'nursing homes',
    'nursing homes' : 'nursing homes', 
    'order freezing utility shut offs' : 'housing',
    'outdoor and recreation' : 'outdoor and recreation', 
    'personal care' : 'personal care', 
    'public gatherings' : 'gatherings',
    'public health advisory system' : 'medical', 
    'quarantine' : 'shelter in place',
    'residential overnight camps' : 'camps',
    'resumed elective medical procedures' : 'medical', 
    'shelter in place' : 'shelter in place',
    'state of emergency' : 'state of emergency', 
    'state of emergency/funds' : 'state of emergency',
    'stop enforcement of evictions' : 'housing', 
    'stop initiation of evictions' : 'housing',
    'suspend elective dental procedures' : 'medical', 
    'training jobs' : 'training jobs', 
    'travel' : 'travel',
    'traveler from out of state' : 'travel', 
    'updated guidelines' : 'updated guidelines',
    'wholesale trade' : 'wholesale trade',
}

min_samples = 3
policy_data_prepped = prep_policy_data(policy_data=policy_data,
                                           policy_dict=policy_dict,
                                           min_samples=min_samples)

# %%
policy_data_prepped
# Out:
#               state policy_level       date               policy_type  \
# 1       Mississippi       county 2020-07-20    outdoor and recreation
# 3          Missouri        state 2020-06-15  non-essential businesses
# 5           Georgia       county 2020-04-30                 childcare
# 6          Missouri       county 2020-05-31             entertainment
# 7          Missouri        state 2021-08-31              mask mandate
# ...             ...          ...        ...                       ...
# 4213       Illinois       county 2021-01-15         houses of worship
# 4214       New York       county 2020-06-08  non-essential businesses
# 4215          Texas       county 2020-07-03              mask mandate
# 4216          Maine       county 2020-05-18    outdoor and recreation
# 4217  West Virginia        state 2020-03-19             entertainment
#
#      start_stop       county  fips_code  \
# 1          stop    sunflower      28133
# 3          stop    statewide         29
# 5          stop       fulton      13121
# 6          stop      jackson      29095
# 7          stop    statewide         29
# ...         ...          ...        ...
# 4213      start         cass      17017
# 4214      start     new york      36061
# 4215      start       morris      48343
# 4216      start  piscataquis      23021
# 4217      start    statewide         54
#
#                                     full_policy
# 1        outdoor and recreation - stop - county
# 3       non-essential businesses - stop - state
# 5                     childcare - stop - county
# 6                 entertainment - stop - county
# 7                   mask mandate - stop - state
# ...                                         ...
# 4213         houses of worship - start - county
# 4214  non-essential businesses - start - county
# 4215              mask mandate - start - county
# 4216    outdoor and recreation - start - county
# 4217              entertainment - start - state
#
# [3628 rows x 8 columns]

# %% [markdown]
# # Fixing Clean policy data

# %%
import os
import pandas as pd
from tabulate import tabulate
from sodapy import Socrata
from tqdm import tqdm
import numpy as np
from datetime import timedelta
from datetime import datetime
import us
import re
#from tqdm import tqdm
from tqdm.notebook import tqdm
from typing import Tuple, Union

df = None
cleaned_timeseries_path = "./data/covid_timeseries_cleaned.csv"
path = "./data/covid_policies.csv"
clean_path = "./data/covid_policies_cleaned.csv"
force_reload = False
force_reclean = False

 # get covid policy data
if df is None:
    if os.path.exists(clean_path) and not force_reclean:
        df = pd.read_csv(clean_path, index_col=0)
        df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
        #return df
    
    df = load_policy_data(path, force_reload)

# remove irrelevant columns
df = df.drop(['geocoded_state', 'comments', 'source', 'total_phases'], axis=1)
# get covid timeseries data
timeseries_df = clean_covid_data(
    df=None,
    clean_path = cleaned_timeseries_path
)

# clean up state names
abbr = [elem.abbr for elem in us.states.STATES]
df = df.drop(df[~df['state_id'].isin(abbr)].index)
df.replace(to_replace=us.states.mapping('abbr', 'name'), inplace=True)
df.rename(columns={'state_id': 'state'}, inplace=True)

### county
# convert nulls in count to 'statewide'
df.fillna(value={'county': 'statewide'}, inplace=True)

# convert to lowercase
df['county'] = df['county'].str.lower()

# address mismatches
county_match = re.compile(" county$")
munici_match = re.compile(" municipality$")
city_match = re.compile(" city$")
Borough_match = re.compile(" borough$")

df['county'].replace(to_replace=county_match, value='', inplace=True)
df['county'].replace(to_replace=munici_match, value='', inplace=True)
df['county'].replace(to_replace=city_match, value='', inplace=True)
df['county'].replace(to_replace=Borough_match, value='', inplace=True)

locs = timeseries_df['county'].unique()
mismatches = [county for county in df['county'][df['county']!='statewide'].unique() 
            if county not in locs]
assert len(mismatches) == 0, f"[ERROR] found mismatches between timeseries and policy dataset: {mismatches}"

# fips code

# %%
for index, data in df.iterrows():
    if data.policy_level == 'state':
        print(us.states.lookup(us.states.mapping("name", "abbr").get(data.state)).fips)
# Out:
# 10
# 29
# 44
# 08
# 44
# 01
# 49
# 53
# 21
# 34
# 19
# 38
# 25
# 24
# 44
# 36
# 37
# 19
# 41
# 41
# 21
# 34
# 09
# 04
# 18
# 46
# 50
# 36
# 17
# 40
# 48
# 13
# 19
# 53
# 36
# 10
# 20
# 35
# 25
# 20
# 25
# 38
# 28
# 35
# 20
# 28
# 22
# 32
# 15
# 39
# 28
# 47
# 22
# 44
# 31
# 16
# 33
# 55
# 02
# 29
# 35
# 53
# 08
# 36
# 18
# 16
# 46
# 27
# 36
# 42
# 45
# 01
# 40
# 05
# 55
# 54

# %%
us.states.lookup(us.states.mapping('name', 'abbr').get("Delaware"))
# Out:
# <State:Delaware>

# %%
policy_data
# Out:
#               state policy_level       date               policy_type  \
# 1       Mississippi       county 2020-07-20    outdoor and recreation
# 3          Missouri        state 2020-06-15  non-essential businesses
# 5           Georgia       county 2020-04-30          childcare (k-12)
# 6          Missouri       county 2020-05-31             entertainment
# 7          Missouri        state 2021-08-31          mask requirement
# ...             ...          ...        ...                       ...
# 4213       Illinois       county 2021-01-15         houses of worship
# 4214       New York       county 2020-06-08  non-essential businesses
# 4215          Texas       county 2020-07-03          mask requirement
# 4216          Maine       county 2020-05-18    outdoor and recreation
# 4217  West Virginia        state 2020-03-19            food and drink
#
#      start_stop       county  fips_code
# 1          stop    sunflower      28133
# 3          stop    statewide         29
# 5          stop       fulton      13121
# 6          stop      jackson      29095
# 7          stop    statewide         29
# ...         ...          ...        ...
# 4213      start         cass      17017
# 4214      start     new york      36061
# 4215      start       morris      48343
# 4216      start  piscataquis      23021
# 4217      start    statewide         54
#
# [3647 rows x 7 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 policy_data_prepped = prep_policy_data(policy_data=policy_data,
# ----> 2                                            policy_dict=policy_dict,
#       3                                            min_samples=min_samples)
#
# NameError: name 'policy_dict' is not defined

# %% [markdown]
# # digging into the prepare_data function

# %%
bins_list = [(0, 4), (5, 999)]


policies: str = None
file_id: Union[str, None] = "test"
save_path: str = "./data/single_policy_bins/"
save_data: bool = True
force_rerun: bool = False
pbar: bool = True
new_df: Union[None, pd.DataFrame] = None

# %%
### reload the dataframe from file if applicable
if file_id is None and isinstance(policies, str):
    file_id = policies
elif file_id is None and not isinstance(policies, str):
    raise ValueError("if passing multiple policies, you must pass a file id")

filename = file_id.replace(" - ", "_") +\
            "-bins=" + ''.join([str(b[0])+"-"+str(b[1])+"_" for b in bins_list])[:-1] + ".csv"

if not force_rerun and os.path.exists(save_path + filename):
    new_df = pd.read_csv(save_path + filename, index_col=0, header=[0, 1])
    new_df[('info', 'date')] = pd.to_datetime(new_df[('info', 'date')], format='%Y-%m-%d')
    #return new_df

### initialize the new dataframe
if new_df is None:
    new_df = prepare_new_df(case_data)

# 3 possible cases for policies:
# 1) None (use all policies)
# 2) str (use this specific policy)
# 3) List (use the given list of policies)

if policies is None:
    policies = policy_data_prepped['full_policy'].unique()
elif isinstance(policies, str):
    policies = [policies]

tuples_policies = [ (p, (str(date_range[0]) + "-" + str(date_range[1])))
                        for p in policies
                        for date_range in bins_list]

cols_polices = pd.MultiIndex.from_tuples(tuples_policies)
policies_df = pd.DataFrame(columns=cols_polices)
new_df = pd.concat([new_df, policies_df])
new_df = new_df.fillna(0)
policy_data_filtered = policy_data_prepped[policy_data_prepped['full_policy'].isin(policies)]

# generate dataframe
df_dict = policy_data_filtered.to_dict('records')

# %%
policies
# Out:
# array(['outdoor and recreation - stop - county',
#        'non-essential businesses - stop - state',
#        'childcare - stop - county', 'entertainment - stop - county',
#        'mask mandate - stop - state',
#        'non-essential businesses - stop - county',
#        'personal care - stop - state', 'shelter in place - stop - county',
#        'gyms - stop - state', 'outdoor and recreation - stop - state',
#        'houses of worship - stop - state',
#        'houses of worship - stop - county', 'childcare - stop - state',
#        'shelter in place - stop - state', 'entertainment - stop - state',
#        'manufacturing - stop - state', 'manufacturing - stop - county',
#        'mask mandate - stop - county', 'personal care - stop - county',
#        'executive order - stop - state', 'manufacturing - start - state',
#        'mask mandate - start - county', 'entertainment - start - county',
#        'childcare - start - state', 'childcare - start - county',
#        'gyms - start - state', 'houses of worship - start - state',
#        'outdoor and recreation - start - county',
#        'shelter in place - start - county', 'medical - start - county',
#        'non-essential businesses - start - state',
#        'mask mandate - start - state', 'housing - start - state',
#        'medical - start - state',
#        'non-essential businesses - start - county',
#        'state of emergency - start - state',
#        'houses of worship - start - county',
#        'outdoor and recreation - start - state',
#        'wholesale trade - start - county',
#        'entertainment - start - state',
#        'shelter in place - start - state',
#        'nursing homes - start - state', 'manufacturing - start - county',
#        'personal care - start - state', 'travel - start - state',
#        'gatherings - start - state', 'education - start - state',
#        'personal care - start - county', 'construction - start - county',
#        'executive order - start - state'], dtype=object)

# %%
df_dict
# Out:
# [{'state': 'Mississippi',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-20 00:00:00'),
#   'policy_type': 'outdoor and recreation',
#   'start_stop': 'stop',
#   'county': 'sunflower',
#   'fips_code': 28133,
#   'full_policy': 'outdoor and recreation - stop - county'},
#  {'state': 'Missouri',
#   'policy_level': 'state',
#   'date': Timestamp('2020-06-15 00:00:00'),
#   'policy_type': 'non-essential businesses',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 29,
#   'full_policy': 'non-essential businesses - stop - state'},
#  {'state': 'Georgia',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-30 00:00:00'),
#   'policy_type': 'childcare',
#   'start_stop': 'stop',
#   'county': 'fulton',
#   'fips_code': 13121,
#   'full_policy': 'childcare - stop - county'},
#  {'state': 'Missouri',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-31 00:00:00'),
#   'policy_type': 'entertainment',
#   'start_stop': 'stop',
#   'county': 'jackson',
#   'fips_code': 29095,
#   'full_policy': 'entertainment - stop - county'},
#  {'state': 'Missouri',
#   'policy_level': 'state',
#   'date': Timestamp('2021-08-31 00:00:00'),
#   'policy_type': 'mask mandate',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 29,
#   'full_policy': 'mask mandate - stop - state'},
#  {'state': 'Mississippi',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-20 00:00:00'),
#   'policy_type': 'non-essential businesses',
#   'start_stop': 'stop',
#   'county': 'jefferson',
#   'fips_code': 28063,
#   'full_policy': 'non-essential businesses - stop - county'},
#  {'state': 'Mississippi',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-20 00:00:00'),
#   'policy_type': 'outdoor and recreation',
#   'start_stop': 'stop',
#   'county': 'grenada',
#   'fips_code': 28043,
#   'full_policy': 'outdoor and recreation - stop - county'},
#  {'state': 'New Mexico',
#   'policy_level': 'state',
#   'date': Timestamp('2020-05-15 00:00:00'),
#   'policy_type': 'personal care',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 35,
#   'full_policy': 'personal care - stop - state'},
#  {'state': 'Mississippi',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-20 00:00:00'),
#   'policy_type': 'entertainment',
#   'start_stop': 'stop',
#   'county': 'quitman',
#   'fips_code': 28119,
#   'full_policy': 'entertainment - stop - county'},
#  {'state': 'California',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-31 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'alameda',
#   'fips_code': 6001,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Delaware',
#   'policy_level': 'state',
#   'date': Timestamp('2020-06-01 00:00:00'),
#   'policy_type': 'gyms',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 10,
#   'full_policy': 'gyms - stop - state'},
#  {'state': 'Mississippi',
#   'policy_level': 'state',
#   'date': Timestamp('2020-09-30 00:00:00'),
#   'policy_type': 'outdoor and recreation',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 28,
#   'full_policy': 'outdoor and recreation - stop - state'},
#  {'state': 'Minnesota',
#   'policy_level': 'state',
#   'date': Timestamp('2020-06-09 00:00:00'),
#   'policy_type': 'houses of worship',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 27,
#   'full_policy': 'houses of worship - stop - state'},
#  {'state': 'Wisconsin',
#   'policy_level': 'state',
#   'date': Timestamp('2020-11-21 00:00:00'),
#   'policy_type': 'mask mandate',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 55,
#   'full_policy': 'mask mandate - stop - state'},
#  {'state': 'Mississippi',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-20 00:00:00'),
#   'policy_type': 'houses of worship',
#   'start_stop': 'stop',
#   'county': 'rankin',
#   'fips_code': 28121,
#   'full_policy': 'houses of worship - stop - county'},
#  {'state': 'Pennsylvania',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-30 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'york',
#   'fips_code': 42133,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Nebraska',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-06 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'dodge',
#   'fips_code': 31053,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Louisiana',
#   'policy_level': 'state',
#   'date': Timestamp('2020-08-07 00:00:00'),
#   'policy_type': 'childcare',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 22,
#   'full_policy': 'childcare - stop - state'},
#  {'state': 'Missouri',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-31 00:00:00'),
#   'policy_type': 'outdoor and recreation',
#   'start_stop': 'stop',
#   'county': 'jackson',
#   'fips_code': 29095,
#   'full_policy': 'outdoor and recreation - stop - county'},
#  {'state': 'Mississippi',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-20 00:00:00'),
#   'policy_type': 'houses of worship',
#   'start_stop': 'stop',
#   'county': 'wayne',
#   'fips_code': 28153,
#   'full_policy': 'houses of worship - stop - county'},
#  {'state': 'Rhode Island',
#   'policy_level': 'state',
#   'date': Timestamp('2020-08-28 00:00:00'),
#   'policy_type': 'outdoor and recreation',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 44,
#   'full_policy': 'outdoor and recreation - stop - state'},
#  {'state': 'Utah',
#   'policy_level': 'state',
#   'date': Timestamp('2020-06-05 00:00:00'),
#   'policy_type': 'houses of worship',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 49,
#   'full_policy': 'houses of worship - stop - state'},
#  {'state': 'Maine',
#   'policy_level': 'state',
#   'date': Timestamp('2020-05-31 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 23,
#   'full_policy': 'shelter in place - stop - state'},
#  {'state': 'Nebraska',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-11 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'morrill',
#   'fips_code': 31123,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Texas',
#   'policy_level': 'state',
#   'date': Timestamp('2020-05-18 00:00:00'),
#   'policy_type': 'gyms',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 48,
#   'full_policy': 'gyms - stop - state'},
#  {'state': 'New Mexico',
#   'policy_level': 'state',
#   'date': Timestamp('2020-06-01 00:00:00'),
#   'policy_type': 'gyms',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 35,
#   'full_policy': 'gyms - stop - state'},
#  {'state': 'Mississippi',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-20 00:00:00'),
#   'policy_type': 'non-essential businesses',
#   'start_stop': 'stop',
#   'county': 'washington',
#   'fips_code': 28151,
#   'full_policy': 'non-essential businesses - stop - county'},
#  {'state': 'Minnesota',
#   'policy_level': 'state',
#   'date': Timestamp('2020-06-09 00:00:00'),
#   'policy_type': 'non-essential businesses',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 27,
#   'full_policy': 'non-essential businesses - stop - state'},
#  {'state': 'Oklahoma',
#   'policy_level': 'state',
#   'date': Timestamp('2020-05-01 00:00:00'),
#   'policy_type': 'entertainment',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 40,
#   'full_policy': 'entertainment - stop - state'},
#  {'state': 'Maine',
#   'policy_level': 'state',
#   'date': Timestamp('2020-06-17 00:00:00'),
#   'policy_type': 'gyms',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 23,
#   'full_policy': 'gyms - stop - state'},
#  {'state': 'Indiana',
#   'policy_level': 'state',
#   'date': Timestamp('2020-05-04 00:00:00'),
#   'policy_type': 'manufacturing',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 18,
#   'full_policy': 'manufacturing - stop - state'},
#  {'state': 'Nebraska',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-06 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'stanton',
#   'fips_code': 31167,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Missouri',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-24 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'linn',
#   'fips_code': 29115,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Texas',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-11 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'zapata',
#   'fips_code': 48505,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Ohio',
#   'policy_level': 'state',
#   'date': Timestamp('2020-07-01 00:00:00'),
#   'policy_type': 'entertainment',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 39,
#   'full_policy': 'entertainment - stop - state'},
#  {'state': 'Iowa',
#   'policy_level': 'county',
#   'date': Timestamp('2020-09-20 00:00:00'),
#   'policy_type': 'entertainment',
#   'start_stop': 'stop',
#   'county': 'dallas',
#   'fips_code': 19049,
#   'full_policy': 'entertainment - stop - county'},
#  {'state': 'Texas',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-03 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'brown',
#   'fips_code': 48049,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Alaska',
#   'policy_level': 'county',
#   'date': Timestamp('2021-01-01 00:00:00'),
#   'policy_type': 'houses of worship',
#   'start_stop': 'stop',
#   'county': 'anchorage',
#   'fips_code': 2020,
#   'full_policy': 'houses of worship - stop - county'},
#  {'state': 'Missouri',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-24 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'webster',
#   'fips_code': 29225,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Texas',
#   'policy_level': 'county',
#   'date': Timestamp('2020-11-13 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'el paso',
#   'fips_code': 48141,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Florida',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-19 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'leon',
#   'fips_code': 12073,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Pennsylvania',
#   'policy_level': 'state',
#   'date': Timestamp('2020-07-03 00:00:00'),
#   'policy_type': 'gyms',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 42,
#   'full_policy': 'gyms - stop - state'},
#  {'state': 'Vermont',
#   'policy_level': 'state',
#   'date': Timestamp('2020-06-15 00:00:00'),
#   'policy_type': 'non-essential businesses',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 50,
#   'full_policy': 'non-essential businesses - stop - state'},
#  {'state': 'Colorado',
#   'policy_level': 'state',
#   'date': Timestamp('2020-12-28 00:00:00'),
#   'policy_type': 'outdoor and recreation',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 8,
#   'full_policy': 'outdoor and recreation - stop - state'},
#  {'state': 'Mississippi',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-20 00:00:00'),
#   'policy_type': 'childcare',
#   'start_stop': 'stop',
#   'county': 'hinds',
#   'fips_code': 28049,
#   'full_policy': 'childcare - stop - county'},
#  {'state': 'New York',
#   'policy_level': 'state',
#   'date': Timestamp('2020-06-30 00:00:00'),
#   'policy_type': 'entertainment',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 36,
#   'full_policy': 'entertainment - stop - state'},
#  {'state': 'Mississippi',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-20 00:00:00'),
#   'policy_type': 'childcare',
#   'start_stop': 'stop',
#   'county': 'sunflower',
#   'fips_code': 28133,
#   'full_policy': 'childcare - stop - county'},
#  {'state': 'Mississippi',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-20 00:00:00'),
#   'policy_type': 'childcare',
#   'start_stop': 'stop',
#   'county': 'jackson',
#   'fips_code': 28059,
#   'full_policy': 'childcare - stop - county'},
#  {'state': 'Nebraska',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-11 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'platte',
#   'fips_code': 31141,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Nevada',
#   'policy_level': 'state',
#   'date': Timestamp('2020-05-29 00:00:00'),
#   'policy_type': 'gyms',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 32,
#   'full_policy': 'gyms - stop - state'},
#  {'state': 'Louisiana',
#   'policy_level': 'state',
#   'date': Timestamp('2020-08-07 00:00:00'),
#   'policy_type': 'entertainment',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 22,
#   'full_policy': 'entertainment - stop - state'},
#  {'state': 'Colorado',
#   'policy_level': 'state',
#   'date': Timestamp('2020-07-01 00:00:00'),
#   'policy_type': 'houses of worship',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 8,
#   'full_policy': 'houses of worship - stop - state'},
#  {'state': 'Alaska',
#   'policy_level': 'state',
#   'date': Timestamp('2020-12-15 00:00:00'),
#   'policy_type': 'outdoor and recreation',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 2,
#   'full_policy': 'outdoor and recreation - stop - state'},
#  {'state': 'Nebraska',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-11 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'banner',
#   'fips_code': 31007,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Texas',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-04 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'coryell',
#   'fips_code': 48099,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Nebraska',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-06 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'saunders',
#   'fips_code': 31155,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Texas',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-04 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'san patricio',
#   'fips_code': 48409,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'California',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-01 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'yolo',
#   'fips_code': 6113,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Alaska',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-05 00:00:00'),
#   'policy_type': 'manufacturing',
#   'start_stop': 'stop',
#   'county': 'anchorage',
#   'fips_code': 2020,
#   'full_policy': 'manufacturing - stop - county'},
#  {'state': 'Mississippi',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-20 00:00:00'),
#   'policy_type': 'childcare',
#   'start_stop': 'stop',
#   'county': 'rankin',
#   'fips_code': 28121,
#   'full_policy': 'childcare - stop - county'},
#  {'state': 'Nebraska',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-11 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'kimball',
#   'fips_code': 31105,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'California',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-03 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'sutter',
#   'fips_code': 6101,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'New Mexico',
#   'policy_level': 'state',
#   'date': Timestamp('2020-08-28 00:00:00'),
#   'policy_type': 'entertainment',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 35,
#   'full_policy': 'entertainment - stop - state'},
#  {'state': 'Texas',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-30 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'cass',
#   'fips_code': 48067,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Pennsylvania',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-30 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'monroe',
#   'fips_code': 42089,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Georgia',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-07 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'decatur',
#   'fips_code': 13087,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Massachusetts',
#   'policy_level': 'state',
#   'date': Timestamp('2020-05-18 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 25,
#   'full_policy': 'shelter in place - stop - state'},
#  {'state': 'Utah',
#   'policy_level': 'state',
#   'date': Timestamp('2020-11-23 00:00:00'),
#   'policy_type': 'entertainment',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 49,
#   'full_policy': 'entertainment - stop - state'},
#  {'state': 'Colorado',
#   'policy_level': 'county',
#   'date': Timestamp('2020-03-26 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'broomfield',
#   'fips_code': 8014,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Texas',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-30 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'swisher',
#   'fips_code': 48437,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Missouri',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-24 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'stoddard',
#   'fips_code': 29207,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Texas',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-30 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'aransas',
#   'fips_code': 48007,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'North Carolina',
#   'policy_level': 'state',
#   'date': Timestamp('2020-06-26 00:00:00'),
#   'policy_type': 'personal care',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 37,
#   'full_policy': 'personal care - stop - state'},
#  {'state': 'Kentucky',
#   'policy_level': 'state',
#   'date': Timestamp('2020-08-09 00:00:00'),
#   'policy_type': 'manufacturing',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 21,
#   'full_policy': 'manufacturing - stop - state'},
#  {'state': 'Indiana',
#   'policy_level': 'state',
#   'date': Timestamp('2020-07-03 00:00:00'),
#   'policy_type': 'childcare',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 18,
#   'full_policy': 'childcare - stop - state'},
#  {'state': 'Wisconsin',
#   'policy_level': 'state',
#   'date': Timestamp('2020-11-06 00:00:00'),
#   'policy_type': 'manufacturing',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 55,
#   'full_policy': 'manufacturing - stop - state'},
#  {'state': 'Pennsylvania',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-30 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'beaver',
#   'fips_code': 42007,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Texas',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-08 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'kaufman',
#   'fips_code': 48257,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Nebraska',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-11 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'greeley',
#   'fips_code': 31077,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Florida',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-09 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'osceola',
#   'fips_code': 12097,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Florida',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-05 00:00:00'),
#   'policy_type': 'non-essential businesses',
#   'start_stop': 'stop',
#   'county': 'palm beach',
#   'fips_code': 12099,
#   'full_policy': 'non-essential businesses - stop - county'},
#  {'state': 'Mississippi',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-20 00:00:00'),
#   'policy_type': 'entertainment',
#   'start_stop': 'stop',
#   'county': 'wayne',
#   'fips_code': 28153,
#   'full_policy': 'entertainment - stop - county'},
#  {'state': 'North Carolina',
#   'policy_level': 'state',
#   'date': Timestamp('2020-05-22 00:00:00'),
#   'policy_type': 'childcare',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 37,
#   'full_policy': 'childcare - stop - state'},
#  {'state': 'Nebraska',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-11 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'mcpherson',
#   'fips_code': 31119,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Oregon',
#   'policy_level': 'state',
#   'date': Timestamp('2020-06-19 00:00:00'),
#   'policy_type': 'gyms',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 41,
#   'full_policy': 'gyms - stop - state'},
#  {'state': 'Iowa',
#   'policy_level': 'state',
#   'date': Timestamp('2020-06-25 00:00:00'),
#   'policy_type': 'non-essential businesses',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 19,
#   'full_policy': 'non-essential businesses - stop - state'},
#  {'state': 'Georgia',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-30 00:00:00'),
#   'policy_type': 'non-essential businesses',
#   'start_stop': 'stop',
#   'county': 'fulton',
#   'fips_code': 13121,
#   'full_policy': 'non-essential businesses - stop - county'},
#  {'state': 'Texas',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-10 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'hays',
#   'fips_code': 48209,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Texas',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-30 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'erath',
#   'fips_code': 48143,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Arizona',
#   'policy_level': 'state',
#   'date': Timestamp('2020-05-31 00:00:00'),
#   'policy_type': 'personal care',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 4,
#   'full_policy': 'personal care - stop - state'},
#  {'state': 'Montana',
#   'policy_level': 'state',
#   'date': Timestamp('2020-06-01 00:00:00'),
#   'policy_type': 'outdoor and recreation',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 30,
#   'full_policy': 'outdoor and recreation - stop - state'},
#  {'state': 'Illinois',
#   'policy_level': 'state',
#   'date': Timestamp('2020-05-30 00:00:00'),
#   'policy_type': 'childcare',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 17,
#   'full_policy': 'childcare - stop - state'},
#  {'state': 'Mississippi',
#   'policy_level': 'county',
#   'date': Timestamp('2020-12-28 00:00:00'),
#   'policy_type': 'mask mandate',
#   'start_stop': 'stop',
#   'county': 'forrest',
#   'fips_code': 28035,
#   'full_policy': 'mask mandate - stop - county'},
#  {'state': 'Texas',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-10 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'jefferson',
#   'fips_code': 48245,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Wyoming',
#   'policy_level': 'state',
#   'date': Timestamp('2020-07-31 00:00:00'),
#   'policy_type': 'non-essential businesses',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 56,
#   'full_policy': 'non-essential businesses - stop - state'},
#  {'state': 'Georgia',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-15 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'cobb',
#   'fips_code': 13067,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Florida',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-30 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'sumter',
#   'fips_code': 12119,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'North Carolina',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-16 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'gaston',
#   'fips_code': 37071,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Utah',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-13 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'salt lake',
#   'fips_code': 49035,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'North Dakota',
#   'policy_level': 'state',
#   'date': Timestamp('2020-05-01 00:00:00'),
#   'policy_type': 'non-essential businesses',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 38,
#   'full_policy': 'non-essential businesses - stop - state'},
#  {'state': 'Massachusetts',
#   'policy_level': 'state',
#   'date': Timestamp('2020-06-08 00:00:00'),
#   'policy_type': 'entertainment',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 25,
#   'full_policy': 'entertainment - stop - state'},
#  {'state': 'Mississippi',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-20 00:00:00'),
#   'policy_type': 'childcare',
#   'start_stop': 'stop',
#   'county': 'madison',
#   'fips_code': 28089,
#   'full_policy': 'childcare - stop - county'},
#  {'state': 'Mississippi',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-20 00:00:00'),
#   'policy_type': 'childcare',
#   'start_stop': 'stop',
#   'county': 'washington',
#   'fips_code': 28151,
#   'full_policy': 'childcare - stop - county'},
#  {'state': 'Mississippi',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-20 00:00:00'),
#   'policy_type': 'non-essential businesses',
#   'start_stop': 'stop',
#   'county': 'claiborne',
#   'fips_code': 28021,
#   'full_policy': 'non-essential businesses - stop - county'},
#  {'state': 'Texas',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-05 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'val verde',
#   'fips_code': 48465,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Nebraska',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-11 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'thomas',
#   'fips_code': 31171,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Florida',
#   'policy_level': 'state',
#   'date': Timestamp('2020-05-18 00:00:00'),
#   'policy_type': 'entertainment',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 12,
#   'full_policy': 'entertainment - stop - state'},
#  {'state': 'Wyoming',
#   'policy_level': 'state',
#   'date': Timestamp('2020-07-31 00:00:00'),
#   'policy_type': 'entertainment',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 56,
#   'full_policy': 'entertainment - stop - state'},
#  {'state': 'Nebraska',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-06 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'hall',
#   'fips_code': 31079,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Vermont',
#   'policy_level': 'state',
#   'date': Timestamp('2020-06-01 00:00:00'),
#   'policy_type': 'gyms',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 50,
#   'full_policy': 'gyms - stop - state'},
#  {'state': 'Mississippi',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-20 00:00:00'),
#   'policy_type': 'childcare',
#   'start_stop': 'stop',
#   'county': 'wayne',
#   'fips_code': 28153,
#   'full_policy': 'childcare - stop - county'},
#  {'state': 'Arizona',
#   'policy_level': 'state',
#   'date': Timestamp('2020-05-31 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 4,
#   'full_policy': 'shelter in place - stop - state'},
#  {'state': 'Mississippi',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-20 00:00:00'),
#   'policy_type': 'childcare',
#   'start_stop': 'stop',
#   'county': 'quitman',
#   'fips_code': 28119,
#   'full_policy': 'childcare - stop - county'},
#  {'state': 'West Virginia',
#   'policy_level': 'state',
#   'date': Timestamp('2020-05-04 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 54,
#   'full_policy': 'shelter in place - stop - state'},
#  {'state': 'Nebraska',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-11 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'sherman',
#   'fips_code': 31163,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Texas',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-15 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'dallas',
#   'fips_code': 48113,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Vermont',
#   'policy_level': 'state',
#   'date': Timestamp('2020-06-15 00:00:00'),
#   'policy_type': 'entertainment',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 50,
#   'full_policy': 'entertainment - stop - state'},
#  {'state': 'Mississippi',
#   'policy_level': 'county',
#   'date': Timestamp('2020-12-12 00:00:00'),
#   'policy_type': 'outdoor and recreation',
#   'start_stop': 'stop',
#   'county': 'forrest',
#   'fips_code': 28035,
#   'full_policy': 'outdoor and recreation - stop - county'},
#  {'state': 'North Carolina',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-29 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'mecklenburg',
#   'fips_code': 37119,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Nebraska',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-11 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'harlan',
#   'fips_code': 31083,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Minnesota',
#   'policy_level': 'state',
#   'date': Timestamp('2020-06-09 00:00:00'),
#   'policy_type': 'outdoor and recreation',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 27,
#   'full_policy': 'outdoor and recreation - stop - state'},
#  {'state': 'Nebraska',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-11 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'custer',
#   'fips_code': 31041,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Texas',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-04 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'willacy',
#   'fips_code': 48489,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Missouri',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-06 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'lincoln',
#   'fips_code': 29113,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Kansas',
#   'policy_level': 'state',
#   'date': Timestamp('2020-05-04 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 20,
#   'full_policy': 'shelter in place - stop - state'},
#  {'state': 'Texas',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-30 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'navarro',
#   'fips_code': 48349,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Arkansas',
#   'policy_level': 'state',
#   'date': Timestamp('2020-05-04 00:00:00'),
#   'policy_type': 'non-essential businesses',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 5,
#   'full_policy': 'non-essential businesses - stop - state'},
#  {'state': 'Mississippi',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-20 00:00:00'),
#   'policy_type': 'manufacturing',
#   'start_stop': 'stop',
#   'county': 'claiborne',
#   'fips_code': 28021,
#   'full_policy': 'manufacturing - stop - county'},
#  {'state': 'Louisiana',
#   'policy_level': 'state',
#   'date': Timestamp('2020-08-07 00:00:00'),
#   'policy_type': 'manufacturing',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 22,
#   'full_policy': 'manufacturing - stop - state'},
#  {'state': 'Missouri',
#   'policy_level': 'state',
#   'date': Timestamp('2020-06-15 00:00:00'),
#   'policy_type': 'manufacturing',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 29,
#   'full_policy': 'manufacturing - stop - state'},
#  {'state': 'Mississippi',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-20 00:00:00'),
#   'policy_type': 'entertainment',
#   'start_stop': 'stop',
#   'county': 'hinds',
#   'fips_code': 28049,
#   'full_policy': 'entertainment - stop - county'},
#  {'state': 'Illinois',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-30 00:00:00'),
#   'policy_type': 'childcare',
#   'start_stop': 'stop',
#   'county': 'cook',
#   'fips_code': 17031,
#   'full_policy': 'childcare - stop - county'},
#  {'state': 'Michigan',
#   'policy_level': 'state',
#   'date': Timestamp('2021-04-19 00:00:00'),
#   'policy_type': 'entertainment',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 26,
#   'full_policy': 'entertainment - stop - state'},
#  {'state': 'Idaho',
#   'policy_level': 'state',
#   'date': Timestamp('2020-05-01 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 16,
#   'full_policy': 'shelter in place - stop - state'},
#  {'state': 'Kansas',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-25 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'atchison',
#   'fips_code': 20005,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Nebraska',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-11 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'nemaha',
#   'fips_code': 31127,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'New Jersey',
#   'policy_level': 'state',
#   'date': Timestamp('2020-06-09 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 34,
#   'full_policy': 'shelter in place - stop - state'},
#  {'state': 'Mississippi',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-20 00:00:00'),
#   'policy_type': 'childcare',
#   'start_stop': 'stop',
#   'county': 'harrison',
#   'fips_code': 28047,
#   'full_policy': 'childcare - stop - county'},
#  {'state': 'Texas',
#   'policy_level': 'state',
#   'date': Timestamp('2020-05-18 00:00:00'),
#   'policy_type': 'outdoor and recreation',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 48,
#   'full_policy': 'outdoor and recreation - stop - state'},
#  {'state': 'Delaware',
#   'policy_level': 'state',
#   'date': Timestamp('2020-05-31 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 10,
#   'full_policy': 'shelter in place - stop - state'},
#  {'state': 'Texas',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-30 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'chambers',
#   'fips_code': 48071,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Nebraska',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-11 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'box butte',
#   'fips_code': 31013,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Mississippi',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-20 00:00:00'),
#   'policy_type': 'childcare',
#   'start_stop': 'stop',
#   'county': 'washington',
#   'fips_code': 28151,
#   'full_policy': 'childcare - stop - county'},
#  {'state': 'Connecticut',
#   'policy_level': 'state',
#   'date': Timestamp('2020-05-20 00:00:00'),
#   'policy_type': 'outdoor and recreation',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 9,
#   'full_policy': 'outdoor and recreation - stop - state'},
#  {'state': 'Colorado',
#   'policy_level': 'state',
#   'date': Timestamp('2020-12-04 00:00:00'),
#   'policy_type': 'manufacturing',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 8,
#   'full_policy': 'manufacturing - stop - state'},
#  {'state': 'Iowa',
#   'policy_level': 'state',
#   'date': Timestamp('2020-06-25 00:00:00'),
#   'policy_type': 'outdoor and recreation',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 19,
#   'full_policy': 'outdoor and recreation - stop - state'},
#  {'state': 'Mississippi',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-20 00:00:00'),
#   'policy_type': 'manufacturing',
#   'start_stop': 'stop',
#   'county': 'desoto',
#   'fips_code': 28033,
#   'full_policy': 'manufacturing - stop - county'},
#  {'state': 'Mississippi',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-20 00:00:00'),
#   'policy_type': 'entertainment',
#   'start_stop': 'stop',
#   'county': 'washington',
#   'fips_code': 28151,
#   'full_policy': 'entertainment - stop - county'},
#  {'state': 'Nebraska',
#   'policy_level': 'state',
#   'date': Timestamp('2020-05-11 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 31,
#   'full_policy': 'shelter in place - stop - state'},
#  {'state': 'Nebraska',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-11 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'clay',
#   'fips_code': 31035,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Pennsylvania',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-30 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'lebanon',
#   'fips_code': 42075,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Mississippi',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-20 00:00:00'),
#   'policy_type': 'childcare',
#   'start_stop': 'stop',
#   'county': 'claiborne',
#   'fips_code': 28021,
#   'full_policy': 'childcare - stop - county'},
#  {'state': 'Alabama',
#   'policy_level': 'state',
#   'date': Timestamp('2020-11-08 00:00:00'),
#   'policy_type': 'outdoor and recreation',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 1,
#   'full_policy': 'outdoor and recreation - stop - state'},
#  {'state': 'Texas',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-01 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'young',
#   'fips_code': 48503,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Texas',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-17 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'montgomery',
#   'fips_code': 48339,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Nebraska',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-11 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'rock',
#   'fips_code': 31149,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Nebraska',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-11 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'keith',
#   'fips_code': 31101,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Oklahoma',
#   'policy_level': 'state',
#   'date': Timestamp('2020-04-24 00:00:00'),
#   'policy_type': 'non-essential businesses',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 40,
#   'full_policy': 'non-essential businesses - stop - state'},
#  {'state': 'Georgia',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-30 00:00:00'),
#   'policy_type': 'personal care',
#   'start_stop': 'stop',
#   'county': 'fulton',
#   'fips_code': 13121,
#   'full_policy': 'personal care - stop - county'},
#  {'state': 'Alaska',
#   'policy_level': 'county',
#   'date': Timestamp('2020-03-31 00:00:00'),
#   'policy_type': 'entertainment',
#   'start_stop': 'stop',
#   'county': 'northwest arctic',
#   'fips_code': 2188,
#   'full_policy': 'entertainment - stop - county'},
#  {'state': 'Oklahoma',
#   'policy_level': 'state',
#   'date': Timestamp('2020-05-06 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 40,
#   'full_policy': 'shelter in place - stop - state'},
#  {'state': 'Tennessee',
#   'policy_level': 'state',
#   'date': Timestamp('2020-04-27 00:00:00'),
#   'policy_type': 'non-essential businesses',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 47,
#   'full_policy': 'non-essential businesses - stop - state'},
#  {'state': 'Georgia',
#   'policy_level': 'state',
#   'date': Timestamp('2020-09-30 00:00:00'),
#   'policy_type': 'childcare',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 13,
#   'full_policy': 'childcare - stop - state'},
#  {'state': 'Utah',
#   'policy_level': 'state',
#   'date': Timestamp('2020-06-05 00:00:00'),
#   'policy_type': 'personal care',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 49,
#   'full_policy': 'personal care - stop - state'},
#  {'state': 'Nebraska',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-06 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'burt',
#   'fips_code': 31021,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Rhode Island',
#   'policy_level': 'state',
#   'date': Timestamp('2020-08-28 00:00:00'),
#   'policy_type': 'non-essential businesses',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 44,
#   'full_policy': 'non-essential businesses - stop - state'},
#  {'state': 'Mississippi',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-20 00:00:00'),
#   'policy_type': 'entertainment',
#   'start_stop': 'stop',
#   'county': 'jackson',
#   'fips_code': 28059,
#   'full_policy': 'entertainment - stop - county'},
#  {'state': 'Texas',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-30 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'refugio',
#   'fips_code': 48391,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Missouri',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-24 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'boone',
#   'fips_code': 29019,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Louisiana',
#   'policy_level': 'state',
#   'date': Timestamp('2020-08-07 00:00:00'),
#   'policy_type': 'entertainment',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 22,
#   'full_policy': 'entertainment - stop - state'},
#  {'state': 'Oregon',
#   'policy_level': 'state',
#   'date': Timestamp('2020-12-02 00:00:00'),
#   'policy_type': 'entertainment',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 41,
#   'full_policy': 'entertainment - stop - state'},
#  {'state': 'Nebraska',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-11 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'buffalo',
#   'fips_code': 31019,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Utah',
#   'policy_level': 'state',
#   'date': Timestamp('2020-05-01 00:00:00'),
#   'policy_type': 'gyms',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 49,
#   'full_policy': 'gyms - stop - state'},
#  {'state': 'Mississippi',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-20 00:00:00'),
#   'policy_type': 'entertainment',
#   'start_stop': 'stop',
#   'county': 'madison',
#   'fips_code': 28089,
#   'full_policy': 'entertainment - stop - county'},
#  {'state': 'Pennsylvania',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-30 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'washington',
#   'fips_code': 42125,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Mississippi',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-20 00:00:00'),
#   'policy_type': 'outdoor and recreation',
#   'start_stop': 'stop',
#   'county': 'desoto',
#   'fips_code': 28033,
#   'full_policy': 'outdoor and recreation - stop - county'},
#  {'state': 'Illinois',
#   'policy_level': 'state',
#   'date': Timestamp('2020-05-30 00:00:00'),
#   'policy_type': 'outdoor and recreation',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 17,
#   'full_policy': 'outdoor and recreation - stop - state'},
#  {'state': 'Mississippi',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-20 00:00:00'),
#   'policy_type': 'entertainment',
#   'start_stop': 'stop',
#   'county': 'quitman',
#   'fips_code': 28119,
#   'full_policy': 'entertainment - stop - county'},
#  {'state': 'California',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-01 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'placer',
#   'fips_code': 6061,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Pennsylvania',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-30 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'cumberland',
#   'fips_code': 42041,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Florida',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-24 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'st. lucie',
#   'fips_code': 12111,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Texas',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-22 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'andrews',
#   'fips_code': 48003,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Nebraska',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-06 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'washington',
#   'fips_code': 31177,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'Missouri',
#   'policy_level': 'state',
#   'date': Timestamp('2020-06-15 00:00:00'),
#   'policy_type': 'childcare',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 29,
#   'full_policy': 'childcare - stop - state'},
#  {'state': 'California',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-15 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'nevada',
#   'fips_code': 6057,
#   'full_policy': 'shelter in place - stop - county'},
#  {'state': 'West Virginia',
#   'policy_level': 'state',
#   'date': Timestamp('2020-05-04 00:00:00'),
#   'policy_type': 'non-essential businesses',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 54,
#   'full_policy': 'non-essential businesses - stop - state'},
#  {'state': 'Michigan',
#   'policy_level': 'state',
#   'date': Timestamp('2020-09-09 00:00:00'),
#   'policy_type': 'gyms',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 26,
#   'full_policy': 'gyms - stop - state'},
#  {'state': 'New Mexico',
#   'policy_level': 'state',
#   'date': Timestamp('2020-08-28 00:00:00'),
#   'policy_type': 'non-essential businesses',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 35,
#   'full_policy': 'non-essential businesses - stop - state'},
#  {'state': 'Wyoming',
#   'policy_level': 'state',
#   'date': Timestamp('2020-07-31 00:00:00'),
#   'policy_type': 'gyms',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 56,
#   'full_policy': 'gyms - stop - state'},
#  {'state': 'Oregon',
#   'policy_level': 'state',
#   'date': Timestamp('2020-05-15 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'stop',
#   'county': 'statewide',
#   'fips_code': 41,
#   'full_policy': 'shelter in place - stop - state'},
#  {'state': 'Texas',
#   'policy_level': 'county',
# ...
#   'fips_code': 48009,
#   'full_policy': 'mask mandate - start - county'},
#  {'state': 'Utah',
#   'policy_level': 'county',
#   'date': Timestamp('2020-11-24 00:00:00'),
#   'policy_type': 'mask mandate',
#   'start_stop': 'start',
#   'county': 'millard',
#   'fips_code': 49027,
#   'full_policy': 'mask mandate - start - county'},
#  {'state': 'Idaho',
#   'policy_level': 'county',
#   'date': Timestamp('2020-10-27 00:00:00'),
#   'policy_type': 'entertainment',
#   'start_stop': 'start',
#   'county': 'twin falls',
#   'fips_code': 16083,
#   'full_policy': 'entertainment - start - county'},
#  {'state': 'New York',
#   'policy_level': 'county',
#   'date': Timestamp('2020-06-08 00:00:00'),
#   'policy_type': 'wholesale trade',
#   'start_stop': 'start',
#   'county': 'bronx',
#   'fips_code': 36005,
#   'full_policy': 'wholesale trade - start - county'},
#  {'state': 'Utah',
#   'policy_level': 'county',
#   'date': Timestamp('2020-09-11 00:00:00'),
#   'policy_type': 'childcare',
#   'start_stop': 'start',
#   'county': 'carbon',
#   'fips_code': 49007,
#   'full_policy': 'childcare - start - county'},
#  {'state': 'South Carolina',
#   'policy_level': 'state',
#   'date': Timestamp('2020-05-22 00:00:00'),
#   'policy_type': 'entertainment',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 45,
#   'full_policy': 'entertainment - start - state'},
#  {'state': 'Colorado',
#   'policy_level': 'state',
#   'date': Timestamp('2020-04-01 00:00:00'),
#   'policy_type': 'medical',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 8,
#   'full_policy': 'medical - start - state'},
#  {'state': 'Nebraska',
#   'policy_level': 'state',
#   'date': Timestamp('2020-04-03 00:00:00'),
#   'policy_type': 'medical',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 31,
#   'full_policy': 'medical - start - state'},
#  {'state': 'Arizona',
#   'policy_level': 'county',
#   'date': Timestamp('2020-08-27 00:00:00'),
#   'policy_type': 'non-essential businesses',
#   'start_stop': 'start',
#   'county': 'la paz',
#   'fips_code': 4012,
#   'full_policy': 'non-essential businesses - start - county'},
#  {'state': 'Illinois',
#   'policy_level': 'state',
#   'date': Timestamp('2021-02-04 00:00:00'),
#   'policy_type': 'mask mandate',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 17,
#   'full_policy': 'mask mandate - start - state'},
#  {'state': 'South Dakota',
#   'policy_level': 'state',
#   'date': Timestamp('2020-04-15 00:00:00'),
#   'policy_type': 'medical',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 46,
#   'full_policy': 'medical - start - state'},
#  {'state': 'Utah',
#   'policy_level': 'county',
#   'date': Timestamp('2020-11-24 00:00:00'),
#   'policy_type': 'entertainment',
#   'start_stop': 'start',
#   'county': 'kane',
#   'fips_code': 49025,
#   'full_policy': 'entertainment - start - county'},
#  {'state': 'Connecticut',
#   'policy_level': 'state',
#   'date': Timestamp('2020-03-16 00:00:00'),
#   'policy_type': 'gyms',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 9,
#   'full_policy': 'gyms - start - state'},
#  {'state': 'Michigan',
#   'policy_level': 'state',
#   'date': Timestamp('2020-03-16 00:00:00'),
#   'policy_type': 'gyms',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 26,
#   'full_policy': 'gyms - start - state'},
#  {'state': 'Texas',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-03 00:00:00'),
#   'policy_type': 'mask mandate',
#   'start_stop': 'start',
#   'county': 'wilbarger',
#   'fips_code': 48487,
#   'full_policy': 'mask mandate - start - county'},
#  {'state': 'Texas',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-03 00:00:00'),
#   'policy_type': 'mask mandate',
#   'start_stop': 'start',
#   'county': 'oldham',
#   'fips_code': 48359,
#   'full_policy': 'mask mandate - start - county'},
#  {'state': 'Indiana',
#   'policy_level': 'state',
#   'date': Timestamp('2020-03-30 00:00:00'),
#   'policy_type': 'medical',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 18,
#   'full_policy': 'medical - start - state'},
#  {'state': 'Nebraska',
#   'policy_level': 'state',
#   'date': Timestamp('2020-07-06 00:00:00'),
#   'policy_type': 'childcare',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 31,
#   'full_policy': 'childcare - start - state'},
#  {'state': 'West Virginia',
#   'policy_level': 'state',
#   'date': Timestamp('2020-03-30 00:00:00'),
#   'policy_type': 'medical',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 54,
#   'full_policy': 'medical - start - state'},
#  {'state': 'Colorado',
#   'policy_level': 'state',
#   'date': Timestamp('2020-06-19 00:00:00'),
#   'policy_type': 'state of emergency',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 8,
#   'full_policy': 'state of emergency - start - state'},
#  {'state': 'Alabama',
#   'policy_level': 'state',
#   'date': Timestamp('2020-09-30 00:00:00'),
#   'policy_type': 'non-essential businesses',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 1,
#   'full_policy': 'non-essential businesses - start - state'},
#  {'state': 'California',
#   'policy_level': 'state',
#   'date': Timestamp('2020-03-23 00:00:00'),
#   'policy_type': 'medical',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 6,
#   'full_policy': 'medical - start - state'},
#  {'state': 'Tennessee',
#   'policy_level': 'state',
#   'date': Timestamp('2021-02-26 00:00:00'),
#   'policy_type': 'houses of worship',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 47,
#   'full_policy': 'houses of worship - start - state'},
#  {'state': 'Nebraska',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-03 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'start',
#   'county': 'cedar',
#   'fips_code': 31027,
#   'full_policy': 'shelter in place - start - county'},
#  {'state': 'Pennsylvania',
#   'policy_level': 'county',
#   'date': Timestamp('2020-03-27 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'start',
#   'county': 'butler',
#   'fips_code': 42019,
#   'full_policy': 'shelter in place - start - county'},
#  {'state': 'New York',
#   'policy_level': 'county',
#   'date': Timestamp('2020-06-08 00:00:00'),
#   'policy_type': 'wholesale trade',
#   'start_stop': 'start',
#   'county': 'richmond',
#   'fips_code': 36085,
#   'full_policy': 'wholesale trade - start - county'},
#  {'state': 'Colorado',
#   'policy_level': 'county',
#   'date': Timestamp('2020-06-06 00:00:00'),
#   'policy_type': 'outdoor and recreation',
#   'start_stop': 'start',
#   'county': 'denver',
#   'fips_code': 8031,
#   'full_policy': 'outdoor and recreation - start - county'},
#  {'state': 'Kentucky',
#   'policy_level': 'state',
#   'date': Timestamp('2020-06-22 00:00:00'),
#   'policy_type': 'entertainment',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 21,
#   'full_policy': 'entertainment - start - state'},
#  {'state': 'Nevada',
#   'policy_level': 'state',
#   'date': Timestamp('2020-03-12 00:00:00'),
#   'policy_type': 'state of emergency',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 32,
#   'full_policy': 'state of emergency - start - state'},
#  {'state': 'Montana',
#   'policy_level': 'state',
#   'date': Timestamp('2020-03-28 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 30,
#   'full_policy': 'shelter in place - start - state'},
#  {'state': 'Nevada',
#   'policy_level': 'state',
#   'date': Timestamp('2020-05-09 00:00:00'),
#   'policy_type': 'mask mandate',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 32,
#   'full_policy': 'mask mandate - start - state'},
#  {'state': 'Utah',
#   'policy_level': 'county',
#   'date': Timestamp('2020-11-24 00:00:00'),
#   'policy_type': 'childcare',
#   'start_stop': 'start',
#   'county': 'emery',
#   'fips_code': 49015,
#   'full_policy': 'childcare - start - county'},
#  {'state': 'Pennsylvania',
#   'policy_level': 'county',
#   'date': Timestamp('2020-03-28 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'start',
#   'county': 'beaver',
#   'fips_code': 42007,
#   'full_policy': 'shelter in place - start - county'},
#  {'state': 'Idaho',
#   'policy_level': 'county',
#   'date': Timestamp('2020-10-27 00:00:00'),
#   'policy_type': 'mask mandate',
#   'start_stop': 'start',
#   'county': 'caribou',
#   'fips_code': 16029,
#   'full_policy': 'mask mandate - start - county'},
#  {'state': 'New York',
#   'policy_level': 'state',
#   'date': Timestamp('2020-03-16 00:00:00'),
#   'policy_type': 'housing',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 36,
#   'full_policy': 'housing - start - state'},
#  {'state': 'New Mexico',
#   'policy_level': 'state',
#   'date': Timestamp('2020-04-30 00:00:00'),
#   'policy_type': 'medical',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 35,
#   'full_policy': 'medical - start - state'},
#  {'state': 'Missouri',
#   'policy_level': 'state',
#   'date': Timestamp('2020-05-04 00:00:00'),
#   'policy_type': 'outdoor and recreation',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 29,
#   'full_policy': 'outdoor and recreation - start - state'},
#  {'state': 'Oklahoma',
#   'policy_level': 'state',
#   'date': Timestamp('2020-03-24 00:00:00'),
#   'policy_type': 'medical',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 40,
#   'full_policy': 'medical - start - state'},
#  {'state': 'Texas',
#   'policy_level': 'county',
#   'date': Timestamp('2020-03-24 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'start',
#   'county': 'tarrant',
#   'fips_code': 48439,
#   'full_policy': 'shelter in place - start - county'},
#  {'state': 'Ohio',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-23 00:00:00'),
#   'policy_type': 'medical',
#   'start_stop': 'start',
#   'county': 'lawrence',
#   'fips_code': 39087,
#   'full_policy': 'medical - start - county'},
#  {'state': 'Ohio',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-16 00:00:00'),
#   'policy_type': 'mask mandate',
#   'start_stop': 'start',
#   'county': 'montgomery',
#   'fips_code': 39113,
#   'full_policy': 'mask mandate - start - county'},
#  {'state': 'Ohio',
#   'policy_level': 'state',
#   'date': Timestamp('2020-03-09 00:00:00'),
#   'policy_type': 'medical',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 39,
#   'full_policy': 'medical - start - state'},
#  {'state': 'Connecticut',
#   'policy_level': 'state',
#   'date': Timestamp('2020-03-09 00:00:00'),
#   'policy_type': 'nursing homes',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 9,
#   'full_policy': 'nursing homes - start - state'},
#  {'state': 'Utah',
#   'policy_level': 'county',
#   'date': Timestamp('2020-04-01 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'start',
#   'county': 'wasatch',
#   'fips_code': 49051,
#   'full_policy': 'shelter in place - start - county'},
#  {'state': 'New Jersey',
#   'policy_level': 'state',
#   'date': Timestamp('2021-01-31 00:00:00'),
#   'policy_type': 'housing',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 34,
#   'full_policy': 'housing - start - state'},
#  {'state': 'North Dakota',
#   'policy_level': 'county',
#   'date': Timestamp('2020-09-03 00:00:00'),
#   'policy_type': 'childcare',
#   'start_stop': 'start',
#   'county': 'walsh',
#   'fips_code': 38099,
#   'full_policy': 'childcare - start - county'},
#  {'state': 'North Dakota',
#   'policy_level': 'county',
#   'date': Timestamp('2020-09-03 00:00:00'),
#   'policy_type': 'outdoor and recreation',
#   'start_stop': 'start',
#   'county': 'griggs',
#   'fips_code': 38039,
#   'full_policy': 'outdoor and recreation - start - county'},
#  {'state': 'Illinois',
#   'policy_level': 'county',
#   'date': Timestamp('2021-01-15 00:00:00'),
#   'policy_type': 'non-essential businesses',
#   'start_stop': 'start',
#   'county': 'douglas',
#   'fips_code': 17041,
#   'full_policy': 'non-essential businesses - start - county'},
#  {'state': 'California',
#   'policy_level': 'county',
#   'date': Timestamp('2020-11-16 00:00:00'),
#   'policy_type': 'non-essential businesses',
#   'start_stop': 'start',
#   'county': 'stanislaus',
#   'fips_code': 6099,
#   'full_policy': 'non-essential businesses - start - county'},
#  {'state': 'Washington',
#   'policy_level': 'state',
#   'date': Timestamp('2020-05-25 00:00:00'),
#   'policy_type': 'manufacturing',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 53,
#   'full_policy': 'manufacturing - start - state'},
#  {'state': 'Wyoming',
#   'policy_level': 'state',
#   'date': Timestamp('2020-06-15 00:00:00'),
#   'policy_type': 'childcare',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 56,
#   'full_policy': 'childcare - start - state'},
#  {'state': 'California',
#   'policy_level': 'county',
#   'date': Timestamp('2020-11-16 00:00:00'),
#   'policy_type': 'entertainment',
#   'start_stop': 'start',
#   'county': 'san diego',
#   'fips_code': 6073,
#   'full_policy': 'entertainment - start - county'},
#  {'state': 'Montana',
#   'policy_level': 'state',
#   'date': Timestamp('2020-04-27 00:00:00'),
#   'policy_type': 'outdoor and recreation',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 30,
#   'full_policy': 'outdoor and recreation - start - state'},
#  {'state': 'New Mexico',
#   'policy_level': 'state',
#   'date': Timestamp('2020-03-19 00:00:00'),
#   'policy_type': 'gyms',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 35,
#   'full_policy': 'gyms - start - state'},
#  {'state': 'Tennessee',
#   'policy_level': 'state',
#   'date': Timestamp('2020-03-30 00:00:00'),
#   'policy_type': 'medical',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 47,
#   'full_policy': 'medical - start - state'},
#  {'state': 'Texas',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-03 00:00:00'),
#   'policy_type': 'mask mandate',
#   'start_stop': 'start',
#   'county': 'jack',
#   'fips_code': 48237,
#   'full_policy': 'mask mandate - start - county'},
#  {'state': 'New Mexico',
#   'policy_level': 'state',
#   'date': Timestamp('2020-03-11 00:00:00'),
#   'policy_type': 'state of emergency',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 35,
#   'full_policy': 'state of emergency - start - state'},
#  {'state': 'Wyoming',
#   'policy_level': 'state',
#   'date': Timestamp('2020-03-13 00:00:00'),
#   'policy_type': 'state of emergency',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 56,
#   'full_policy': 'state of emergency - start - state'},
#  {'state': 'Minnesota',
#   'policy_level': 'state',
#   'date': Timestamp('2020-03-28 00:00:00'),
#   'policy_type': 'medical',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 27,
#   'full_policy': 'medical - start - state'},
#  {'state': 'Arkansas',
#   'policy_level': 'state',
#   'date': Timestamp('2020-04-27 00:00:00'),
#   'policy_type': 'medical',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 5,
#   'full_policy': 'medical - start - state'},
#  {'state': 'Maine',
#   'policy_level': 'county',
#   'date': Timestamp('2020-05-11 00:00:00'),
#   'policy_type': 'non-essential businesses',
#   'start_stop': 'start',
#   'county': 'washington',
#   'fips_code': 23029,
#   'full_policy': 'non-essential businesses - start - county'},
#  {'state': 'Colorado',
#   'policy_level': 'state',
#   'date': Timestamp('2021-02-06 00:00:00'),
#   'policy_type': 'entertainment',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 8,
#   'full_policy': 'entertainment - start - state'},
#  {'state': 'Louisiana',
#   'policy_level': 'state',
#   'date': Timestamp('2020-03-13 00:00:00'),
#   'policy_type': 'medical',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 22,
#   'full_policy': 'medical - start - state'},
#  {'state': 'Mississippi',
#   'policy_level': 'state',
#   'date': Timestamp('2020-04-01 00:00:00'),
#   'policy_type': 'shelter in place',
#   'start_stop': 'start',
#   'county': 'statewide',
#   'fips_code': 28,
#   'full_policy': 'shelter in place - start - state'},
#  {'state': 'Michigan',
#   'policy_level': 'county',
#   'date': Timestamp('2020-07-31 00:00:00'),
#   'policy_type': 'entertainment',
#   'start_stop': 'start',
#   'county': 'grand traverse',
#   'fips_code': 26055,
#   'full_policy': 'entertainment - start - county'},
#  ...]

# %%
for row in df_dict:
    for date_bin in bins_list:
        date_range = get_date_range(row['date'], date_bin[0], date_bin[1])
        label = (str(date_bin[0]) + "-" + str(date_bin[1]))
        print(row)
        label = (str(date_bin[0]) + "-" + str(date_bin[1]))
        new_df.loc[(new_df[('info', 'date')].isin(date_range)) &\
                          ((new_df[('info', 'county')] == row['county']) | (row['policy_level'] == 'state')) &\
                           (new_df[('info', 'state')] == row['state']), (policy_name, label)] = 1
    break
# Out:
# {'state': 'Mississippi', 'policy_level': 'county', 'date': Timestamp('2020-07-20 00:00:00'), 'policy_type': 'outdoor and recreation', 'start_stop': 'stop', 'county': 'sunflower', 'fips_code': 28133, 'full_policy': 'outdoor and recreation - stop - county'}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 9
#       5     print(row)
#       6     label = (str(date_bin[0]) + "-" + str(date_bin[1]))
#       7     new_df.loc[(new_df[('info', 'date')].isin(date_range)) &\
#       8                       ((new_df[('info', 'county')] == row['county']) | (row['policy_level'] == 'state')) &\
# ----> 9                        (new_df[('info', 'state')] == row['state']), (policy_name, label)] = 1
#      10 break
#
# NameError: name 'policy_name' is not defined

# %%
new_df.loc[(new_df[('info', 'date')].isin(date_range)) &\
                          ((new_df[('info', 'county')] == row['county']) | (row['policy_level'] == 'state')) &\
                           (new_df[('info', 'state')] == row['state']), (policy_name, label)]
# Out:
#                  info                                             \
#         location_type    state   county       date new_cases_1e6
# 87200          county  Alabama  autauga 2020-01-22          0.00
# 87201          county  Alabama  autauga 2020-01-23          0.00
# 87202          county  Alabama  autauga 2020-01-24          0.00
# 87203          county  Alabama  autauga 2020-01-25          0.00
# 87204          county  Alabama  autauga 2020-01-26          0.00
# ...               ...      ...      ...        ...           ...
# 3513774        county  Wyoming   weston 2021-12-26          0.00
# 3513775        county  Wyoming   weston 2021-12-27         14.08
# 3513776        county  Wyoming   weston 2021-12-28         28.17
# 3513777        county  Wyoming   weston 2021-12-29         42.25
# 3513778        county  Wyoming   weston 2021-12-30         28.17
#
#                                                                \
#         new_deaths_1e6 new_cases_7day_1e6 new_deaths_7day_1e6
# 87200              0.0           0.000000                 0.0
# 87201              0.0           0.000000                 0.0
# 87202              0.0           0.000000                 0.0
# 87203              0.0           0.000000                 0.0
# 87204              0.0           0.000000                 0.0
# ...                ...                ...                 ...
# 3513774            0.0          20.140845                 0.0
# 3513775            0.0          12.112676                 0.0
# 3513776            0.0          12.112676                 0.0
# 3513777            0.0          18.169014                 0.0
# 3513778            0.0          16.056338                 0.0
#
#         outdoor and recreation - stop - county  \
#                                            0-4
# 87200                                        0
# 87201                                        0
# 87202                                        0
# 87203                                        0
# 87204                                        0
# ...                                        ...
# 3513774                                      0
# 3513775                                      0
# 3513776                                      0
# 3513777                                      0
# 3513778                                      0
#
#         non-essential businesses - stop - state  ...  \
#                                             0-4  ...
# 87200                                         0  ...
# 87201                                         0  ...
# 87202                                         0  ...
# 87203                                         0  ...
# 87204                                         0  ...
# ...                                         ...  ...
# 3513774                                       0  ...
# 3513775                                       0  ...
# 3513776                                       0  ...
# 3513777                                       0  ...
# 3513778                                       0  ...
#
#         shelter in place - start - state nursing homes - start - state  \
#                                    5-999                         5-999
# 87200                                  0                             0
# 87201                                  0                             0
# 87202                                  0                             0
# 87203                                  0                             0
# 87204                                  0                             0
# ...                                  ...                           ...
# 3513774                                0                             0
# 3513775                                0                             0
# 3513776                                0                             0
# 3513777                                0                             0
# 3513778                                0                             0
#
#         manufacturing - start - county personal care - start - state  \
#                                  5-999                         5-999
# 87200                                0                             0
# 87201                                0                             0
# 87202                                0                             0
# 87203                                0                             0
# 87204                                0                             0
# ...                                ...                           ...
# 3513774                              0                             0
# 3513775                              0                             0
# 3513776                              0                             0
# 3513777                              0                             0
# 3513778                              0                             0
#
#         travel - start - state gatherings - start - state  \
#                          5-999                      5-999
# 87200                        0                          0
# 87201                        0                          0
# 87202                        0                          0
# 87203                        0                          0
# 87204                        0                          0
# ...                        ...                        ...
# 3513774                      0                          0
# 3513775                      0                          0
# 3513776                      0                          0
# 3513777                      0                          0
# 3513778                      0                          0
#
#         education - start - state personal care - start - county  \
#                             5-999                          5-999
# 87200                           0                              0
# 87201                           0                              0
# 87202                           0                              0
# 87203                           0                              0
# 87204                           0                              0
# ...                           ...                            ...
# 3513774                         0                              0
# 3513775                         0                              0
# 3513776                         0                              0
# 3513777                         0                              0
# 3513778                         0                              0
#
#         construction - start - county executive order - start - state
#                                 5-999                           5-999
# 87200                               0                               0
# 87201                               0                               0
# 87202                               0                               0
# 87203                               0                               0
# 87204                               0                               0
# ...                               ...                             ...
# 3513774                             0                               0
# 3513775                             0                               0
# 3513776                             0                               0
# 3513777                             0                               0
# 3513778                             0                               0
#
# [2228387 rows x 108 columns]
