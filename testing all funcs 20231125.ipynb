# %% [markdown]
# # Testing out all funcs to try to get down what I've done so far

# %%
from covid_project import data_utils as du

# %%
covid_data = du.load_covid_data()

# %%
policy_data = du.load_policy_data()
policy_data.head()
# Out:
#   state_id policy_level                     date               policy_type  \
# 0       DE        state  2020-07-06T00:00:00.000                   Phase 1
# 1       MS       county  2020-07-20T00:00:00.000    Outdoor and Recreation
# 2       PR        state  2020-06-15T00:00:00.000  Non-Essential Businesses
# 3       MO        state  2020-06-15T00:00:00.000  Non-Essential Businesses
# 4       DE        state  2020-09-05T00:00:00.000                   Phase 2
#
#   start_stop                                           comments  \
# 0       stop  Policy_Details: Governor Carney extended Delaw...
# 1       stop  Policy_Details: Executive Order by Governor Ta...
# 2       stop  Policy_Details: Retail - 50% \nPersonal Care -...
# 3       stop  Policy_Details: All industries: practice socia...
# 4       stop  Policy_Details: Governor Carney formally exten...
#
#                                               source  \
# 0  sip_submission_form: https://governor.delaware...
# ...

# %%
from covid_project.policy_mappings import policy_dict_v2
du.get_all_policies(policy_dict_v2, 3)
# Out:
# array(['outdoor and recreation - stop - county',
#        'non-essential businesses - stop - state',
#        'childcare - stop - county', 'entertainment - stop - county',
#        'mask mandate - stop - state',
#        'non-essential businesses - stop - county',
#        'personal care - stop - state', 'shelter in place - stop - county',
#        'gyms - stop - state', 'outdoor and recreation - stop - state',
#        'houses of worship - stop - state',
#        'houses of worship - stop - county', 'childcare - stop - state',
#        'shelter in place - stop - state', 'entertainment - stop - state',
#        'manufacturing - stop - state', 'manufacturing - stop - county',
#        'mask mandate - stop - county', 'personal care - stop - county',
#        'executive order - stop - state', 'manufacturing - start - state',
#        'mask mandate - start - county', 'entertainment - start - county',
#        'childcare - start - state', 'childcare - start - county',
# ...

# %%
df = du.clean_covid_data()

# %%
df
# Out:
#               uid location_type  fips_code   county    state       date  \
# 91440    84001001        county       1001  autauga  Alabama 2020-01-22
# 91441    84001001        county       1001  autauga  Alabama 2020-01-23
# 91442    84001001        county       1001  autauga  Alabama 2020-01-24
# 91443    84001001        county       1001  autauga  Alabama 2020-01-25
# 91444    84001001        county       1001  autauga  Alabama 2020-01-26
# ...           ...           ...        ...      ...      ...        ...
# 3684593  84056045        county      56045   weston  Wyoming 2021-12-26
# 3684594  84056045        county      56045   weston  Wyoming 2021-12-27
# 3684595  84056045        county      56045   weston  Wyoming 2021-12-28
# 3684596  84056045        county      56045   weston  Wyoming 2021-12-29
# 3684597  84056045        county      56045   weston  Wyoming 2021-12-30
#
#          total_population  cumulative_cases  cumulative_cases_1e6  \
# ...

# %%
du.get_cases(df, level='national')
# Out:
#             new_cases_1e6  new_deaths_1e6  new_cases_7day_1e6  \
# date
# 2020-01-22       0.000000        0.000000            0.000000
# 2020-01-23       0.000000        0.000000            0.000000
# 2020-01-24       0.000006        0.000000            0.000000
# 2020-01-25       0.000000        0.000000            0.000000
# 2020-01-26       0.000019        0.000000            0.000007
# ...                   ...             ...                 ...
# 2021-12-26      13.035313        0.150300           35.545285
# 2021-12-27      90.505935        0.750102           40.882680
# 2021-12-28      68.130277        0.960434           44.981066
# 2021-12-29     104.846114        0.848904           50.661505
# 2021-12-30      91.149013        0.525336           57.987196
#
#             new_deaths_7day_1e6
# date
# 2020-01-22             0.000000
# 2020-01-23             0.000000
# 2020-01-24             0.000000
# 2020-01-25             0.000000
# 2020-01-26             0.000000
# ...
